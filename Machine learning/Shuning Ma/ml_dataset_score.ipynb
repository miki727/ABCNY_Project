# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ml_dataset.csv')
df
# Out:
#                                            Original Name  \
# 0                             JAM'YAH TA'AWUN AL-ISLAMIA
# 1                             GLOBOVISION TELE CA, CORP.
# 2                                   KOREAN PEOPLE'S ARMY
# 3                                    RANCHO LA HERRADURA
# 4                                    TECHNO ENERGY, S.A.
# ...                                                  ...
# 18503                                 GLOBAL AGE LIMITED
# 18504  OBSHCHESTVO S OGRANICHENNOI OTVETSTVENNOSTYU M...
# 18505                         AHMED, Qassim Abdullah Ali
# 18506                      JINGHO TECHNOLOGY CO. LIMITED
# 18507                NHEMA, Chenayaimoyo Dunstan Francis
#
#                                           Test Case Name    Test Type  \
# 0                             JAM'YAH TA'AWUN AL-ISLAMIA  Fuzzy Match
# 1                             GLOBOVISION TELE CA, CORP.  Fuzzy Match
# ...

# %%
score = pd.read_excel('GWU_Final Bridger Scores.xlsx')
score
# Out:
#       index      UID             Theme                 Category  \
# 0         0    UID-3  Positive Control              Exact Match
# 1         1    UID-3  Positive Control              Exact Match
# 2         2    UID-3  Positive Control              Exact Match
# 3         3    UID-3  Positive Control              Exact Match
# 4         4    UID-3  Positive Control              Exact Match
# ...     ...      ...               ...                      ...
# 4622   4622  UID-541    Name Additions  Name Part in the Middle
# 4623   4623  UID-541    Name Additions  Name Part in the Middle
# 4624   4624  UID-541    Name Additions  Name Part in the Middle
# 4625   4625  UID-541    Name Additions  Name Part in the Middle
# 4626   4626  UID-541    Name Additions  Name Part in the Middle
#
#             Sub-category Entity-Type    Test Case ID OFAC List UID  \
# 0       100% true match       Entity     UID-3 - 217          6936
# ...

# %%
score = list(score['BRIDGER SCORE'])
score.extend([100] * 4627)
score.extend([0] * 9254)
len(score)
# Out:
# 18508

# %%
df['Bridger Score'] = score
df
# Out:
#                                            Original Name  \
# 0                             JAM'YAH TA'AWUN AL-ISLAMIA
# 1                             GLOBOVISION TELE CA, CORP.
# 2                                   KOREAN PEOPLE'S ARMY
# 3                                    RANCHO LA HERRADURA
# 4                                    TECHNO ENERGY, S.A.
# ...                                                  ...
# 18503                                 GLOBAL AGE LIMITED
# 18504  OBSHCHESTVO S OGRANICHENNOI OTVETSTVENNOSTYU M...
# 18505                         AHMED, Qassim Abdullah Ali
# 18506                      JINGHO TECHNOLOGY CO. LIMITED
# 18507                NHEMA, Chenayaimoyo Dunstan Francis
#
#                                           Test Case Name    Test Type  \
# 0                             JAM'YAH TA'AWUN AL-ISLAMIA  Fuzzy Match
# 1                             GLOBOVISION TELE CA, CORP.  Fuzzy Match
# ...

# %%
df.to_csv('ml_dataset_score.csv', index = False)
