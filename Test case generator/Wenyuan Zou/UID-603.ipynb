# %%
# -----------------------------------
# TEST CASE TYPE REFERENCE INFORMATION
# -----------------------------------

uid = 'UID-603' 
theme = 'Special Characters and Spaces'
category = 'Additional Spaces'
sub_category = 'Abnormally large number of spaces between Name Parts'
entity_type = 'Vessel'

# ********************

# %%
import pandas as pd

# download the OFAC list from the web

ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == 'vessel')] # only evaluate vessel


ofac_list_filtered = ofac_list_filtered[(ofac_list_filtered.name.str.count(' ') > 0)] # only evaluate names with more than 2 words
ofac_list_sampled = ofac_list_filtered.sample(n = 10)

ofac_list_sampled
# Out:
#          uid              name entity_type
# 2755   15042        DIAMOND II      vessel
# 5795   23741           PO CHON      vessel
# 3732   17094     PO THONG GANG      vessel
# 7411   28014     MANUELA SAENZ      vessel
# 5791   23737           PAEK MA      vessel
# 10290  37071      GASRET ALIEV      vessel
# 3729   17091          DOK CHON      vessel
# 3224   15905         MARIA III      vessel
# 5781   23727         NAM SAN 8      vessel
# 10267  37048  MEKHANIK PYATLIN      vessel

# %%
# create blank final test cases table

final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %%
def print_df(df):
    return df.style.set_properties(**{'white-space': 'pre'})

# %%
for index, row in ofac_list_sampled.iterrows():
        number_of_words = row['name'].count(' ') + 1 # determine for each name the number of words
        name_words=row['name'].split()
        if number_of_words==2:
            final_test_name=name_words[0]+' '+' '+' '+' '+' '+' '+' '+' '+name_words[1]
        else:
            final_test_name=name_words[0]+' '+' '+' '+' '+' '+' '+' '+' '+name_words[1]+' '+name_words[2]

        final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe
print_df(final_test_cases)
# Out:
# <style  type="text/css" >
# #T_65ad9_row0_col0,#T_65ad9_row0_col1,#T_65ad9_row0_col2,#T_65ad9_row0_col3,#T_65ad9_row0_col4,#T_65ad9_row0_col5,#T_65ad9_row0_col6,#T_65ad9_row0_col7,#T_65ad9_row0_col8,#T_65ad9_row1_col0,#T_65ad9_row1_col1,#T_65ad9_row1_col2,#T_65ad9_row1_col3,#T_65ad9_row1_col4,#T_65ad9_row1_col5,#T_65ad9_row1_col6,#T_65ad9_row1_col7,#T_65ad9_row1_col8,#T_65ad9_row2_col0,#T_65ad9_row2_col1,#T_65ad9_row2_col2,#T_65ad9_row2_col3,#T_65ad9_row2_col4,#T_65ad9_row2_col5,#T_65ad9_row2_col6,#T_65ad9_row2_col7,#T_65ad9_row2_col8,#T_65ad9_row3_col0,#T_65ad9_row3_col1,#T_65ad9_row3_col2,#T_65ad9_row3_col3,#T_65ad9_row3_col4,#T_65ad9_row3_col5,#T_65ad9_row3_col6,#T_65ad9_row3_col7,#T_65ad9_row3_col8,#T_65ad9_row4_col0,#T_65ad9_row4_col1,#T_65ad9_row4_col2,#T_65ad9_row4_col3,#T_65ad9_row4_col4,#T_65ad9_row4_col5,#T_65ad9_row4_col6,#T_65ad9_row4_col7,#T_65ad9_row4_col8,#T_65ad9_row5_col0,#T_65ad9_row5_col1,#T_65ad9_row5_col2,#T_65ad9_row5_col3,#T_65ad9_row5_col4,#T_65ad9_row5_col5,#T_65ad9_row5_col6,#T_65ad9_row5_col7,#T_65ad9_row5_col8,#T_65ad9_row6_col0,#T_65ad9_row6_col1,#T_65ad9_row6_col2,#T_65ad9_row6_col3,#T_65ad9_row6_col4,#T_65ad9_row6_col5,#T_65ad9_row6_col6,#T_65ad9_row6_col7,#T_65ad9_row6_col8,#T_65ad9_row7_col0,#T_65ad9_row7_col1,#T_65ad9_row7_col2,#T_65ad9_row7_col3,#T_65ad9_row7_col4,#T_65ad9_row7_col5,#T_65ad9_row7_col6,#T_65ad9_row7_col7,#T_65ad9_row7_col8,#T_65ad9_row8_col0,#T_65ad9_row8_col1,#T_65ad9_row8_col2,#T_65ad9_row8_col3,#T_65ad9_row8_col4,#T_65ad9_row8_col5,#T_65ad9_row8_col6,#T_65ad9_row8_col7,#T_65ad9_row8_col8,#T_65ad9_row9_col0,#T_65ad9_row9_col1,#T_65ad9_row9_col2,#T_65ad9_row9_col3,#T_65ad9_row9_col4,#T_65ad9_row9_col5,#T_65ad9_row9_col6,#T_65ad9_row9_col7,#T_65ad9_row9_col8{
#             white-space:  pre;
#         }</style><table id="T_65ad9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >UID</th>        <th class="col_heading level0 col1" >Theme</th>        <th class="col_heading level0 col2" >Category</th>        <th class="col_heading level0 col3" >Sub-category</th>        <th class="col_heading level0 col4" >Entity-Type</th>        <th class="col_heading level0 col5" >Test Case ID</th>        <th class="col_heading level0 col6" >OFAC List UID</th>        <th class="col_heading level0 col7" >Original Name</th>        <th class="col_heading level0 col8" >Test Case Name</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_65ad9_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_65ad9_row0_col0" class="data row0 col0" >UID-603</td>
#                         <td id="T_65ad9_row0_col1" class="data row0 col1" >Special Characters and Spaces</td>
#                         <td id="T_65ad9_row0_col2" class="data row0 col2" >Additional Spaces</td>
#                         <td id="T_65ad9_row0_col3" class="data row0 col3" >Abnormally large number of spaces between Name Parts</td>
#                         <td id="T_65ad9_row0_col4" class="data row0 col4" >Vessel</td>
#                         <td id="T_65ad9_row0_col5" class="data row0 col5" >UID-603 - 2755</td>
#                         <td id="T_65ad9_row0_col6" class="data row0 col6" >15042</td>
#                         <td id="T_65ad9_row0_col7" class="data row0 col7" >DIAMOND II</td>
#                         <td id="T_65ad9_row0_col8" class="data row0 col8" >DIAMOND        II</td>
#             </tr>
#             <tr>
#                         <th id="T_65ad9_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_65ad9_row1_col0" class="data row1 col0" >UID-603</td>
#                         <td id="T_65ad9_row1_col1" class="data row1 col1" >Special Characters and Spaces</td>
#                         <td id="T_65ad9_row1_col2" class="data row1 col2" >Additional Spaces</td>
#                         <td id="T_65ad9_row1_col3" class="data row1 col3" >Abnormally large number of spaces between Name Parts</td>
#                         <td id="T_65ad9_row1_col4" class="data row1 col4" >Vessel</td>
#                         <td id="T_65ad9_row1_col5" class="data row1 col5" >UID-603 - 5795</td>
#                         <td id="T_65ad9_row1_col6" class="data row1 col6" >23741</td>
#                         <td id="T_65ad9_row1_col7" class="data row1 col7" >PO CHON</td>
#                         <td id="T_65ad9_row1_col8" class="data row1 col8" >PO        CHON</td>
#             </tr>
#             <tr>
#                         <th id="T_65ad9_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_65ad9_row2_col0" class="data row2 col0" >UID-603</td>
#                         <td id="T_65ad9_row2_col1" class="data row2 col1" >Special Characters and Spaces</td>
#                         <td id="T_65ad9_row2_col2" class="data row2 col2" >Additional Spaces</td>
#                         <td id="T_65ad9_row2_col3" class="data row2 col3" >Abnormally large number of spaces between Name Parts</td>
#                         <td id="T_65ad9_row2_col4" class="data row2 col4" >Vessel</td>
#                         <td id="T_65ad9_row2_col5" class="data row2 col5" >UID-603 - 3732</td>
#                         <td id="T_65ad9_row2_col6" class="data row2 col6" >17094</td>
#                         <td id="T_65ad9_row2_col7" class="data row2 col7" >PO THONG GANG</td>
#                         <td id="T_65ad9_row2_col8" class="data row2 col8" >PO        THONG GANG</td>
#             </tr>
#             <tr>
#                         <th id="T_65ad9_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_65ad9_row3_col0" class="data row3 col0" >UID-603</td>
#                         <td id="T_65ad9_row3_col1" class="data row3 col1" >Special Characters and Spaces</td>
#                         <td id="T_65ad9_row3_col2" class="data row3 col2" >Additional Spaces</td>
#                         <td id="T_65ad9_row3_col3" class="data row3 col3" >Abnormally large number of spaces between Name Parts</td>
#                         <td id="T_65ad9_row3_col4" class="data row3 col4" >Vessel</td>
#                         <td id="T_65ad9_row3_col5" class="data row3 col5" >UID-603 - 7411</td>
#                         <td id="T_65ad9_row3_col6" class="data row3 col6" >28014</td>
#                         <td id="T_65ad9_row3_col7" class="data row3 col7" >MANUELA SAENZ</td>
#                         <td id="T_65ad9_row3_col8" class="data row3 col8" >MANUELA        SAENZ</td>
#             </tr>
#             <tr>
#                         <th id="T_65ad9_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_65ad9_row4_col0" class="data row4 col0" >UID-603</td>
#                         <td id="T_65ad9_row4_col1" class="data row4 col1" >Special Characters and Spaces</td>
#                         <td id="T_65ad9_row4_col2" class="data row4 col2" >Additional Spaces</td>
#                         <td id="T_65ad9_row4_col3" class="data row4 col3" >Abnormally large number of spaces between Name Parts</td>
#                         <td id="T_65ad9_row4_col4" class="data row4 col4" >Vessel</td>
#                         <td id="T_65ad9_row4_col5" class="data row4 col5" >UID-603 - 5791</td>
#                         <td id="T_65ad9_row4_col6" class="data row4 col6" >23737</td>
#                         <td id="T_65ad9_row4_col7" class="data row4 col7" >PAEK MA</td>
#                         <td id="T_65ad9_row4_col8" class="data row4 col8" >PAEK        MA</td>
#             </tr>
#             <tr>
#                         <th id="T_65ad9_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_65ad9_row5_col0" class="data row5 col0" >UID-603</td>
#                         <td id="T_65ad9_row5_col1" class="data row5 col1" >Special Characters and Spaces</td>
#                         <td id="T_65ad9_row5_col2" class="data row5 col2" >Additional Spaces</td>
#                         <td id="T_65ad9_row5_col3" class="data row5 col3" >Abnormally large n
