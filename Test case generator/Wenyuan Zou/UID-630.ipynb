# %%
# -----------------------------------
# TEST CASE TYPE REFERENCE INFORMATION
# -----------------------------------

uid = 'UID-630' 
theme = 'IDs'
category = 'IMO'
sub_category = 'IMO # without prefix ("IMO")'
entity_type = 'Vessel'

# ********************

# %%
import pandas as pd

# download the OFAC list from the web

ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %%
ofac_list = ofac_list_download[[0,1,2,11]]
ofac_list.columns = ['uid', 'name', 'entity_type','IMO']
ofac_list_imo = ofac_list[ofac_list['IMO'].str.contains('IMO')==True]
ofac_list_imo
# Out:
#          uid                                   name entity_type  \
# 75      4243                                  EBANO      vessel
# 76      4249                                  TIFON      vessel
# 603     7831                         DUMONT, Lionel  individual
# 711     8096  HAMRAOUI, Kamel Ben Mouldi Ben Hassan  individual
# 1059    9339          ARRIOLA MARQUEZ, Oscar Arturo  individual
# ...      ...                                    ...         ...
# 10753  38397    GOLDEN WARRIOR SHIPPING CO. LIMITED        -0-
# 10756  38418                          GLORY HARVEST      vessel
# 10823  39117                           VIRGO MARINE        -0-
# 10886  39276                             GAS ALLURE      vessel
# 10901  39356            NEW EASTERN SHIPPING CO LTD        -0-
#
#                                                      IMO
# 75     Vessel Registration Identification IMO 7406784...
# 76       Vessel Registration Identification IMO 7206512.
# ...

# %%
ofac_list_filtered = ofac_list_imo[(ofac_list_imo.entity_type == 'vessel')]



ofac_list_sampled = ofac_list_filtered.sample(n = 10)
ofac_list_sampled


#ofac_list_filtered = ofac_list_imo[(ofac_list_imo.entity_type == 'vessel')]


#ofac_list_sampled = ofac_list_filtered.sample(n = 10)

#ofac_list_sampled
# Out:
#          uid              name entity_type  \
# 6531   25708             FAXON      vessel
# 6295   25372             BEHTA      vessel
# 3725   17087   HWANG GUM SAN 2      vessel
# 4414   19592            MI RIM      vessel
# 7414   28017              YARE      vessel
# 6309   25386           PARSHAN      vessel
# 6197   25258             GILDA      vessel
# 7190   27148               SIG      vessel
# 10252  37031       BELOMORSKIY      vessel
# 6981   26661  BICENTENARIO III      vessel
#
#                                                      IMO
# 6531   Additional Sanctions Information - Subject to ...
# 6295   Additional Sanctions Information - Subject to ...
# 3725   Secondary sanctions risk: North Korea Sanction...
# 4414   Secondary sanctions risk: North Korea Sanction...
# 7414   Vessel Registration Identification IMO 9543500...
# 6309   Additional Sanctions Information - Subject to ...
# 6197   Additional Sanctions Information - Subject to ...
# ...

# %%
ofac_list_sampled.iloc[1]['IMO'].split(';')
# Out:
# ['Former Vessel Flag Malta',
#  ' alt. Former Vessel Flag Tuvalu',
#  ' alt. Former Vessel Flag None Identified',
#  ' alt. Former Vessel Flag Seychelles',
#  ' Additional Sanctions Information - Subject to Secondary Sanctions',
#  ' Vessel Registration Identification IMO 9357365',
#  ' MMSI 249256000',
#  ' Linked To: NATIONAL IRANIAN TANKER COMPANY.']

# %%
test = ofac_list_sampled['IMO'].str.split(pat = 'IMO', n = 1, expand = True)
ofac_list_sampled['IMO']= test[1]
ofac_list_sampled
#test2= test['1'].str.split(pat = ';', n = 1, expand = True)
# Out:
#          uid              name entity_type  \
# 6531   25708             FAXON      vessel
# 6295   25372             BEHTA      vessel
# 3725   17087   HWANG GUM SAN 2      vessel
# 4414   19592            MI RIM      vessel
# 7414   28017              YARE      vessel
# 6309   25386           PARSHAN      vessel
# 6197   25258             GILDA      vessel
# 7190   27148               SIG      vessel
# 10252  37031       BELOMORSKIY      vessel
# 6981   26661  BICENTENARIO III      vessel
#
#                                                      IMO
# 6531    9283758; Linked To: NATIONAL IRANIAN TANKER C...
# 6295    9349590; Linked To: ISLAMIC REPUBLIC OF IRAN ...
# 3725                                            8405270.
# 4414          8713471; Linked To: MIRIM SHIPPING CO LTD.
# 7414    9543500; Linked To: PETROLEOS DE VENEZUELA, S.A.
# 6309    9051648; Linked To: ISLAMIC REPUBLIC OF IRAN ...
# 6197    9367982; Linked To: ISLAMIC REPUBLIC OF IRAN ...
# ...

# %%
test2= ofac_list_sampled['IMO'].str.split(pat = ';', n = 1, expand = True)
ofac_list_sampled['IMO1']= test2[0]
ofac_list_sampled
# Out:
#          uid              name entity_type  \
# 6531   25708             FAXON      vessel
# 6295   25372             BEHTA      vessel
# 3725   17087   HWANG GUM SAN 2      vessel
# 4414   19592            MI RIM      vessel
# 7414   28017              YARE      vessel
# 6309   25386           PARSHAN      vessel
# 6197   25258             GILDA      vessel
# 7190   27148               SIG      vessel
# 10252  37031       BELOMORSKIY      vessel
# 6981   26661  BICENTENARIO III      vessel
#
#                                                      IMO       IMO1
# 6531    9283758; Linked To: NATIONAL IRANIAN TANKER C...    9283758
# 6295    9349590; Linked To: ISLAMIC REPUBLIC OF IRAN ...    9349590
# 3725                                            8405270.   8405270.
# 4414          8713471; Linked To: MIRIM SHIPPING CO LTD.    8713471
# 7414    9543500; Linked To: PETROLEOS DE VENEZUELA, S.A.    9543500
# 6309    9051648; Linked To: ISLAMIC REPUBLIC OF IRAN ...    9051648
# ...

# %%
ofac_list_sampled['index_column'] = ofac_list_sampled.index
ofac_list_sampled
# Out:
#          uid              name entity_type  \
# 6531   25708             FAXON      vessel
# 6295   25372             BEHTA      vessel
# 3725   17087   HWANG GUM SAN 2      vessel
# 4414   19592            MI RIM      vessel
# 7414   28017              YARE      vessel
# 6309   25386           PARSHAN      vessel
# 6197   25258             GILDA      vessel
# 7190   27148               SIG      vessel
# 10252  37031       BELOMORSKIY      vessel
# 6981   26661  BICENTENARIO III      vessel
#
#                                                      IMO       IMO1  \
# 6531    9283758; Linked To: NATIONAL IRANIAN TANKER C...    9283758
# 6295    9349590; Linked To: ISLAMIC REPUBLIC OF IRAN ...    9349590
# 3725                                            8405270.   8405270.
# 4414          8713471; Linked To: MIRIM SHIPPING CO LTD.    8713471
# 7414    9543500; Linked To: PETROLEOS DE VENEZUELA, S.A.    9543500
# 6309    9051648; Linked To: ISLAMIC REPUBLIC OF IRAN ...    9051648
# ...

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %%
for i in range(10):
    final_test_name=ofac_list_sampled['IMO1'].iloc[i]
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(ofac_list_sampled['index_column'].iloc[i]), ofac_list_sampled['uid'].iloc[i], ofac_list_sampled['name'].iloc[i], final_test_name] # append to the dataframe
final_test_cases
# Out:
#        UID Theme Category                  Sub-category Entity-Type  \
# 0  UID-630   IDs      IMO  IMO # without prefix ("IMO")      Vessel
# 1  UID-630   IDs      IMO  IMO # without prefix ("IMO")      Vessel
# 2  UID-630   IDs      IMO  IMO # without prefix ("IMO")      Vessel
# 3  UID-630   IDs      IMO  IMO # without prefix ("IMO")      Vessel
# 4  UID-630   IDs      IMO  IMO # without prefix ("IMO")      Vessel
# 5  UID-630   IDs      IMO  IMO # without prefix ("IMO")      Vessel
# 6  UID-630   IDs      IMO  IMO # without prefix ("IMO")      Vessel
# 7  UID-630   IDs      IMO  IMO # without prefix ("IMO")      Vessel
# 8  UID-630   IDs      IMO  IMO # without prefix ("IMO")      Vessel
# 9  UID-630   IDs      IMO  IMO # without prefix ("IMO")      Vessel
#
#       Test Case ID OFAC List UID     Original Name Test Case Name
# 0   UID-630 - 6531         25708             FAXON        9283758
# 1   UID-630 - 6295         25372             BEHTA        9349590
# ...
