# %%
# -----------------------------------
# TEST CASE TYPE REFERENCE INFORMATION
# -----------------------------------

uid = 'UID-604' 
theme = 'Special Characters and Spaces'
category = 'Additional Spaces'
sub_category = 'Abnormally large number of spaces in the name parts'
entity_type = 'Vessel'

# ********************

# %%
def multi_space(phrase):        
    phrase = phrase[0] +' '+' '+' '+' '+' '+' '+' '+' '+ phrase[1:]

    return phrase

# %%
import pandas as pd

# download the OFAC list from the web

ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == 'vessel')] # only evaluate vessel


ofac_list_filtered = ofac_list_filtered[(ofac_list_filtered.name.str.count(' ') > 0)] # only evaluate names with more than 2 words
ofac_list_sampled = ofac_list_filtered.sample(n = 10)

ofac_list_sampled
# Out:
#          uid              name entity_type
# 9948   36276      SEA RHAPSODY      vessel
# 4060   18337        BLUE DREAM      vessel
# 2796   15085           SONIA I      vessel
# 10259  37040  KAPITAN SAKHAROV      vessel
# 3723   17085      BAEK MA KANG      vessel
# 5463   23150         WON SAN 2      vessel
# 2763   15050           HERO II      vessel
# 4410   19588        CHONG BONG      vessel
# 2768   15055       HAPPINESS I      vessel
# 10694  37933          BS BRAVO      vessel

# %%
# create blank final test cases table

final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %%
def print_df(df):
    return df.style.set_properties(**{'white-space': 'pre'})

# %%
for index, row in ofac_list_sampled.iterrows():
        number_of_words = row['name'].count(' ') + 1 # determine for each name the number of words
        name_words=row['name'].split()
        final_test_name_test=''
        for i in range(1,number_of_words):
            final_test_name_test=final_test_name_test+' '+name_words[i]+' '
        final_test_name=multi_space(name_words[0])+final_test_name_test
        final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe
print_df(final_test_cases)
# Out:
# <style  type="text/css" >
# #T_a88a0_row0_col0,#T_a88a0_row0_col1,#T_a88a0_row0_col2,#T_a88a0_row0_col3,#T_a88a0_row0_col4,#T_a88a0_row0_col5,#T_a88a0_row0_col6,#T_a88a0_row0_col7,#T_a88a0_row0_col8,#T_a88a0_row1_col0,#T_a88a0_row1_col1,#T_a88a0_row1_col2,#T_a88a0_row1_col3,#T_a88a0_row1_col4,#T_a88a0_row1_col5,#T_a88a0_row1_col6,#T_a88a0_row1_col7,#T_a88a0_row1_col8,#T_a88a0_row2_col0,#T_a88a0_row2_col1,#T_a88a0_row2_col2,#T_a88a0_row2_col3,#T_a88a0_row2_col4,#T_a88a0_row2_col5,#T_a88a0_row2_col6,#T_a88a0_row2_col7,#T_a88a0_row2_col8,#T_a88a0_row3_col0,#T_a88a0_row3_col1,#T_a88a0_row3_col2,#T_a88a0_row3_col3,#T_a88a0_row3_col4,#T_a88a0_row3_col5,#T_a88a0_row3_col6,#T_a88a0_row3_col7,#T_a88a0_row3_col8,#T_a88a0_row4_col0,#T_a88a0_row4_col1,#T_a88a0_row4_col2,#T_a88a0_row4_col3,#T_a88a0_row4_col4,#T_a88a0_row4_col5,#T_a88a0_row4_col6,#T_a88a0_row4_col7,#T_a88a0_row4_col8,#T_a88a0_row5_col0,#T_a88a0_row5_col1,#T_a88a0_row5_col2,#T_a88a0_row5_col3,#T_a88a0_row5_col4,#T_a88a0_row5_col5,#T_a88a0_row5_col6,#T_a88a0_row5_col7,#T_a88a0_row5_col8,#T_a88a0_row6_col0,#T_a88a0_row6_col1,#T_a88a0_row6_col2,#T_a88a0_row6_col3,#T_a88a0_row6_col4,#T_a88a0_row6_col5,#T_a88a0_row6_col6,#T_a88a0_row6_col7,#T_a88a0_row6_col8,#T_a88a0_row7_col0,#T_a88a0_row7_col1,#T_a88a0_row7_col2,#T_a88a0_row7_col3,#T_a88a0_row7_col4,#T_a88a0_row7_col5,#T_a88a0_row7_col6,#T_a88a0_row7_col7,#T_a88a0_row7_col8,#T_a88a0_row8_col0,#T_a88a0_row8_col1,#T_a88a0_row8_col2,#T_a88a0_row8_col3,#T_a88a0_row8_col4,#T_a88a0_row8_col5,#T_a88a0_row8_col6,#T_a88a0_row8_col7,#T_a88a0_row8_col8,#T_a88a0_row9_col0,#T_a88a0_row9_col1,#T_a88a0_row9_col2,#T_a88a0_row9_col3,#T_a88a0_row9_col4,#T_a88a0_row9_col5,#T_a88a0_row9_col6,#T_a88a0_row9_col7,#T_a88a0_row9_col8{
#             white-space:  pre;
#         }</style><table id="T_a88a0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >UID</th>        <th class="col_heading level0 col1" >Theme</th>        <th class="col_heading level0 col2" >Category</th>        <th class="col_heading level0 col3" >Sub-category</th>        <th class="col_heading level0 col4" >Entity-Type</th>        <th class="col_heading level0 col5" >Test Case ID</th>        <th class="col_heading level0 col6" >OFAC List UID</th>        <th class="col_heading level0 col7" >Original Name</th>        <th class="col_heading level0 col8" >Test Case Name</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a88a0_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a88a0_row0_col0" class="data row0 col0" >UID-604</td>
#                         <td id="T_a88a0_row0_col1" class="data row0 col1" >Special Characters and Spaces</td>
#                         <td id="T_a88a0_row0_col2" class="data row0 col2" >Additional Spaces</td>
#                         <td id="T_a88a0_row0_col3" class="data row0 col3" >Abnormally large number of spaces in the name parts</td>
#                         <td id="T_a88a0_row0_col4" class="data row0 col4" >Vessel</td>
#                         <td id="T_a88a0_row0_col5" class="data row0 col5" >UID-604 - 9948</td>
#                         <td id="T_a88a0_row0_col6" class="data row0 col6" >36276</td>
#                         <td id="T_a88a0_row0_col7" class="data row0 col7" >SEA RHAPSODY</td>
#                         <td id="T_a88a0_row0_col8" class="data row0 col8" >S        EA RHAPSODY </td>
#             </tr>
#             <tr>
#                         <th id="T_a88a0_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a88a0_row1_col0" class="data row1 col0" >UID-604</td>
#                         <td id="T_a88a0_row1_col1" class="data row1 col1" >Special Characters and Spaces</td>
#                         <td id="T_a88a0_row1_col2" class="data row1 col2" >Additional Spaces</td>
#                         <td id="T_a88a0_row1_col3" class="data row1 col3" >Abnormally large number of spaces in the name parts</td>
#                         <td id="T_a88a0_row1_col4" class="data row1 col4" >Vessel</td>
#                         <td id="T_a88a0_row1_col5" class="data row1 col5" >UID-604 - 4060</td>
#                         <td id="T_a88a0_row1_col6" class="data row1 col6" >18337</td>
#                         <td id="T_a88a0_row1_col7" class="data row1 col7" >BLUE DREAM</td>
#                         <td id="T_a88a0_row1_col8" class="data row1 col8" >B        LUE DREAM </td>
#             </tr>
#             <tr>
#                         <th id="T_a88a0_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a88a0_row2_col0" class="data row2 col0" >UID-604</td>
#                         <td id="T_a88a0_row2_col1" class="data row2 col1" >Special Characters and Spaces</td>
#                         <td id="T_a88a0_row2_col2" class="data row2 col2" >Additional Spaces</td>
#                         <td id="T_a88a0_row2_col3" class="data row2 col3" >Abnormally large number of spaces in the name parts</td>
#                         <td id="T_a88a0_row2_col4" class="data row2 col4" >Vessel</td>
#                         <td id="T_a88a0_row2_col5" class="data row2 col5" >UID-604 - 2796</td>
#                         <td id="T_a88a0_row2_col6" class="data row2 col6" >15085</td>
#                         <td id="T_a88a0_row2_col7" class="data row2 col7" >SONIA I</td>
#                         <td id="T_a88a0_row2_col8" class="data row2 col8" >S        ONIA I </td>
#             </tr>
#             <tr>
#                         <th id="T_a88a0_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_a88a0_row3_col0" class="data row3 col0" >UID-604</td>
#                         <td id="T_a88a0_row3_col1" class="data row3 col1" >Special Characters and Spaces</td>
#                         <td id="T_a88a0_row3_col2" class="data row3 col2" >Additional Spaces</td>
#                         <td id="T_a88a0_row3_col3" class="data row3 col3" >Abnormally large number of spaces in the name parts</td>
#                         <td id="T_a88a0_row3_col4" class="data row3 col4" >Vessel</td>
#                         <td id="T_a88a0_row3_col5" class="data row3 col5" >UID-604 - 10259</td>
#                         <td id="T_a88a0_row3_col6" class="data row3 col6" >37040</td>
#                         <td id="T_a88a0_row3_col7" class="data row3 col7" >KAPITAN SAKHAROV</td>
#                         <td id="T_a88a0_row3_col8" class="data row3 col8" >K        APITAN SAKHAROV </td>
#             </tr>
#             <tr>
#                         <th id="T_a88a0_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_a88a0_row4_col0" class="data row4 col0" >UID-604</td>
#                         <td id="T_a88a0_row4_col1" class="data row4 col1" >Special Characters and Spaces</td>
#                         <td id="T_a88a0_row4_col2" class="data row4 col2" >Additional Spaces</td>
#                         <td id="T_a88a0_row4_col3" class="data row4 col3" >Abnormally large number of spaces in the name parts</td>
#                         <td id="T_a88a0_row4_col4" class="data row4 col4" >Vessel</td>
#                         <td id="T_a88a0_row4_col5" class="data row4 col5" >UID-604 - 3723</td>
#                         <td id="T_a88a0_row4_col6" class="data row4 col6" >17085</td>
#                         <td id="T_a88a0_row4_col7" class="data row4 col7" >BAEK MA KANG</td>
#                         <td id="T_a88a0_row4_col8" class="data row4 col8" >B        AEK MA  KANG </td>
#             </tr>
#             <tr>
#                         <th id="T_a88a0_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_a88a0_row5_col0" class="data row5 col0" >UID-604</td>
#                         <td id="T_a88a0_row5_col1" class="data row5 col1" >Special Characters and Spaces</td>
#                         <td id="T_a88a0_row5_col2" class="data row5 col2" >Additional Spaces</td>
#                         <td id="T_a88a0_row5_col3" class="data row5 col3
