# %%
# -----------------------------------
# TEST CASE TYPE REFERENCE INFORMATION
# -----------------------------------

uid = 'UID-568' 
theme = 'Names where Name Parts are Modified'
category = 'Repetitions'
sub_category = '1 letter repeated twice'
entity_type = 'Vessel'

# ********************

# %%
import random
def repetition_random_character_twice(phrase,k):
    for num in random.sample(range(0, len(phrase)),k):
        phrase = phrase[:num] +phrase[num]+phrase[num]+ phrase[num:]
    return phrase

# %%
import pandas as pd
from test_case_generator_functions import alphabet

# download the OFAC list from the web

ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %%
ofac_list_filtered= ofac_list[(ofac_list.entity_type == 'vessel')] # only evaluate vessel

# %%
ofac_list_sampled = ofac_list_filtered.sample(n = 10)
ofac_list_sampled
# Out:
#          uid               name entity_type
# 5620   23428               ZEUS      vessel
# 6248   25311             NESHAT      vessel
# 5995   24512           PARTIZAN      vessel
# 10474  37482               NEGA      vessel
# 7014   26704          ESPERANZA      vessel
# 6257   25322  HYUNDAI MIPO 2657      vessel
# 6242   25305           GOLAFRUZ      vessel
# 7410   28012              ICARO      vessel
# 2764   15051              HENNA      vessel
# 6247   25310             MAHNAM      vessel

# %%
# create blank final test cases table

final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %%
# run loop to generate the test cases

for index, row in ofac_list_sampled.iterrows():
        number_of_words = row['name'].count(' ') + 1 # determine for each name the number of words
        name_words=row['name'].split()
        if number_of_words==1:
            final_test_name=repetition_random_character_twice(name_words[0],1)
            final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe
        if number_of_words==2 :
            final_test_name=name_words[0]+' '+repetition_random_character_twice(name_words[1],1)
            final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe
        elif number_of_words==3 :
            final_test_name=name_words[0]+' '+repetition_random_character_twice(name_words[1],1)+' '+name_words[2]
            final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe
       # else:
        #    name_words=row['name'].split()
         #   final_test_name_0=''
          #  for i in range(2,len(name_words)):
           #     final_test_name_0=final_test_name_0+' '+name_words[i]
            #final_test_name=name_words[0]+' '+repetition_random_character_twice(name_words[1],1)+' '+final_test_name_0# create the test case
            #final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

            

final_test_cases      

final_test_cases
# Out:
#        UID                                Theme     Category  \
# 0  UID-568  Names where Name Parts are Modified  Repetitions
# 1  UID-568  Names where Name Parts are Modified  Repetitions
# 2  UID-568  Names where Name Parts are Modified  Repetitions
# 3  UID-568  Names where Name Parts are Modified  Repetitions
# 4  UID-568  Names where Name Parts are Modified  Repetitions
# 5  UID-568  Names where Name Parts are Modified  Repetitions
# 6  UID-568  Names where Name Parts are Modified  Repetitions
# 7  UID-568  Names where Name Parts are Modified  Repetitions
# 8  UID-568  Names where Name Parts are Modified  Repetitions
# 9  UID-568  Names where Name Parts are Modified  Repetitions
#
#               Sub-category Entity-Type     Test Case ID OFAC List UID  \
# 0  1 letter repeated twice      Vessel   UID-568 - 5620         23428
# 1  1 letter repeated twice      Vessel   UID-568 - 6248         25311
# 2  1 letter repeated twice      Vessel   UID-568 - 5995         24512
# 3  1 letter repeated twice      Vessel  UID-568 - 10474         37482
# 4  1 letter repeated twice      Vessel   UID-568 - 7014         26704
# 5  1 letter repeated twice      Vessel   UID-568 - 6257         25322
# 6  1 letter repeated twice      Vessel   UID-568 - 6242         25305
# 7  1 letter repeated twice      Vessel   UID-568 - 7410         28012
# 8  1 letter repeated twice      Vessel   UID-568 - 2764         15051
# 9  1 letter repeated twice      Vessel   UID-568 - 6247         25310
#
#        Original Name       Test Case Name
# 0               ZEUS               ZZZEUS
# 1             NESHAT             NEEESHAT
# 2           PARTIZAN           PARTTTIZAN
# 3               NEGA               NEGGGA
# 4          ESPERANZA          ESPPPERANZA
# 5  HYUNDAI MIPO 2657  HYUNDAI MIPOOO 2657
# 6           GOLAFRUZ           GOLLLAFRUZ
# 7              ICARO              ICAAARO
# 8              HENNA              HENNNNA
# 9             MAHNAM             MMMAHNAM
