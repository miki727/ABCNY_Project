# %%
# -----------------------------------
# TEST CASE TYPE REFERENCE INFORMATION
# -----------------------------------

uid = 'UID-582' 
theme = 'Names where Name Parts are Modified'
category = 'Truncation'
sub_category = '>2 Letter Truncation in a middle name part'
entity_type = 'Vessel'

# ********************

# %%
import random

def truncation_middle(phrase,k):
    for num in random.sample(range(1, len(phrase)-k),1):
        phrase = phrase[:num] + phrase[num+k:]
        
    return phrase#,num,len(phrase),len(phrase)-k

# %%
truncation_middle('ABCDEFG',3)
# Out:
# 'AEFG'

# %%
import pandas as pd

# download the OFAC list from the web

ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %%
# new data frame with split value columns
ofac_split = ofac_list["name"].str.split(" ", n = 2, expand = True)


# making separate first name column from new data frame
ofac_list["First Name"]= ofac_split[0]
 
#making separate middle name column from new data frame
ofac_list["Middle Name"]= ofac_split[1]

# making separate last name column from new data frame

ofac_list["Last Name"]= ofac_split[2]

 
ofac_list_filtered = ofac_list[(ofac_list.entity_type == 'vessel')& (ofac_list['Middle Name'].str.len()>4)  ] # only evaluate vessel

ofac_list_filtered = ofac_list_filtered[(ofac_list_filtered.name.str.count(' ') >1)]

ofac_list_sampled = ofac_list_filtered.sample(n = 10)
ofac_list_sampled
# Out:
# <ipython-input-48-994df41a26c8>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ofac_list["First Name"]= ofac_split[0]
# <ipython-input-48-994df41a26c8>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ofac_list["Middle Name"]= ofac_split[1]
# <ipython-input-48-994df41a26c8>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ofac_list["Last Name"]= ofac_split[2]
#         uid                        name entity_type First Name Middle Name  \
# 5781  23726                CHON MYONG 1      vessel       CHON       MYONG
# 6218  25281              IRAN HORMUZ 25      vessel       IRAN      HORMUZ
# 4419  19597              THAE PYONG SAN      vessel       THAE       PYONG
# 3732  17094               PO THONG GANG      vessel         PO       THONG
# 5809  23776               XIN GUANG HAI      vessel        XIN       GUANG
# 7282  27304              ADRIAN DARYA 1      vessel     ADRIAN       DARYA
# 7411  28013  LUISA CACERES DE ARISMENDI      vessel      LUISA     CACERES
# 2786  15075          BELEMA LIGHT CRUDE      vessel     BELEMA       LIGHT
# 6220  25283              IRAN HORMUZ 12      vessel       IRAN      HORMUZ
# 5811  23778               ASIA BRIDGE 1      vessel       ASIA      BRIDGE
#
#          Last Name
# 5781             1
# 6218            25
# 4419           SAN
# 3732          GANG
# 5809           HAI
# 7282             1
# 7411  DE ARISMENDI
# 2786         CRUDE
# 6220            12
# 5811             1

# %%
# create blank final test cases table

final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %%
# run loop to generate the test cases

for index, row in ofac_list_sampled.iterrows():
        number_of_words = row['name'].count(' ') + 1 # determine for each name the number of words
        name_words=row['name'].split()
        
        if number_of_words==3 :
            final_test_name=name_words[0]+' '+truncation_middle(name_words[1],3)+' '+name_words[2]
            final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe
 
        else:
            name_words=row['name'].split()
            final_test_name_0=''
            for i in range(2,len(name_words)):
                final_test_name_0=final_test_name_0+' '+name_words[i]
            final_test_name=name_words[0]+' '+truncation_middle(name_words[1],3)+' '+final_test_name_0# create the test case
            final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

            

final_test_cases      

final_test_cases
# Out:
#        UID                                Theme    Category  \
# 0  UID-582  Names where Name Parts are Modified  Truncation
# 1  UID-582  Names where Name Parts are Modified  Truncation
# 2  UID-582  Names where Name Parts are Modified  Truncation
# 3  UID-582  Names where Name Parts are Modified  Truncation
# 4  UID-582  Names where Name Parts are Modified  Truncation
# 5  UID-582  Names where Name Parts are Modified  Truncation
# 6  UID-582  Names where Name Parts are Modified  Truncation
# 7  UID-582  Names where Name Parts are Modified  Truncation
# 8  UID-582  Names where Name Parts are Modified  Truncation
# 9  UID-582  Names where Name Parts are Modified  Truncation
#
#                                  Sub-category Entity-Type    Test Case ID  \
# 0  >2 Letter Truncation in a middle name part      Vessel  UID-582 - 5781
# 1  >2 Letter Truncation in a middle name part      Vessel  UID-582 - 6218
# 2  >2 Letter Truncation in a middle name part      Vessel  UID-582 - 4419
# 3  >2 Letter Truncation in a middle name part      Vessel  UID-582 - 3732
# 4  >2 Letter Truncation in a middle name part      Vessel  UID-582 - 5809
# 5  >2 Letter Truncation in a middle name part      Vessel  UID-582 - 7282
# 6  >2 Letter Truncation in a middle name part      Vessel  UID-582 - 7411
# 7  >2 Letter Truncation in a middle name part      Vessel  UID-582 - 2786
# 8  >2 Letter Truncation in a middle name part      Vessel  UID-582 - 6220
# 9  >2 Letter Truncation in a middle name part      Vessel  UID-582 - 5811
#
#   OFAC List UID               Original Name            Test Case Name
# 0         23726                CHON MYONG 1                 CHON MG 1
# 1         25281              IRAN HORMUZ 25               IRAN HUZ 25
# 2         19597              THAE PYONG SAN               THAE PG SAN
# 3         17094               PO THONG GANG                PO TG GANG
# 4         23776               XIN GUANG HAI                XIN GG HAI
# 5         27304              ADRIAN DARYA 1               ADRIAN DA 1
# 6         28013  LUISA CACERES DE ARISMENDI  LUISA CRES  DE ARISMENDI
# 7         15075          BELEMA LIGHT CRUDE           BELEMA LT CRUDE
# 8         25283              IRAN HORMUZ 12               IRAN HOZ 12
# 9         23778               ASIA BRIDGE 1                ASIA BGE 1
