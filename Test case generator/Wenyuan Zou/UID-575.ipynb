# %%
# -----------------------------------
# TEST CASE TYPE REFERENCE INFORMATION
# -----------------------------------

uid = 'UID-575' 
theme = 'Names where Name Parts are Modified'
category = 'Transpositions'
sub_category = '2 transpositions (different name part)'
entity_type = 'Vessel'

# ********************

# %%
import random
def transport_anywhere(phrase,k):
    for num in random.sample(range(0, len(phrase)-1),k):
        if phrase[num+1] != phrase[num]:
            phrase = phrase[:num] +phrase[num+1]+phrase[num]+ phrase[num+2:]
        else:
            phrase = phrase[:num+1] +phrase[num+2]+phrase[num+1]+ phrase[num+3:]
    return phrase

# %%
import pandas as pd

# download the OFAC list from the web

ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %%
# new data frame with split value columns
ofac_split = ofac_list["name"].str.split(" ", n = 2, expand = True)


# making separate first name column from new data frame
ofac_list["First Name"]= ofac_split[0]
 
# making separate middle name column from new data frame
ofac_list["Middle Name"]= ofac_split[1]

# making separate last name column from new data frame

ofac_list["Last Name"]= ofac_split[2]

 
ofac_list_filtered = ofac_list[(ofac_list.entity_type == 'vessel')& (ofac_list['First Name'].str.len()>4) & (ofac_list['Middle Name'].str.len()>3)] # only evaluate vessel

ofac_list_filtered = ofac_list_filtered[(ofac_list_filtered.name.str.count(' ') >0)]

ofac_list_sampled = ofac_list_filtered.sample(n = 10)
ofac_list_sampled
# Out:
# <ipython-input-13-f87cf758f440>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ofac_list["First Name"]= ofac_split[0]
# <ipython-input-13-f87cf758f440>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ofac_list["Middle Name"]= ofac_split[1]
# <ipython-input-13-f87cf758f440>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# create blank final test cases table

final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %%
# run loop to generate the test cases

for index, row in ofac_list_sampled.iterrows():
        number_of_words = row['name'].count(' ') + 1 # determine for each name the number of words
        name_words=row['name'].split()
        
        if number_of_words==2 :
            final_test_name=transport_anywhere(name_words[0],1)+' '+transport_anywhere(name_words[1],1)
            final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe
        elif number_of_words==3 :
            final_test_name=transport_anywhere(name_words[0],1)+' '+transport_anywhere(name_words[1],1)+' '+name_words[2]
            final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe
        else:
            name_words=row['name'].split()
            final_test_name_0=''
            for i in range(2,len(name_words)):
                final_test_name_0=final_test_name_0+' '+name_words[i]
            final_test_name=transport_anywhere(name_words[0],1)+' '+transport_anywhere(name_words[1],1)+' '+final_test_name_0# create the test case
            final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

            

final_test_cases      

final_test_cases
# Out:
#        UID                                Theme        Category  \
# 0  UID-575  Names where Name Parts are Modified  Transpositions
# 1  UID-575  Names where Name Parts are Modified  Transpositions
# 2  UID-575  Names where Name Parts are Modified  Transpositions
# 3  UID-575  Names where Name Parts are Modified  Transpositions
# 4  UID-575  Names where Name Parts are Modified  Transpositions
# 5  UID-575  Names where Name Parts are Modified  Transpositions
# 6  UID-575  Names where Name Parts are Modified  Transpositions
# 7  UID-575  Names where Name Parts are Modified  Transpositions
# 8  UID-575  Names where Name Parts are Modified  Transpositions
# 9  UID-575  Names where Name Parts are Modified  Transpositions
#
#                              Sub-category Entity-Type    Test Case ID  \
# 0  2 transpositions (different name part)      Vessel  UID-575 - 8151
# 1  2 transpositions (different name part)      Vessel  UID-575 - 4400
# ...
