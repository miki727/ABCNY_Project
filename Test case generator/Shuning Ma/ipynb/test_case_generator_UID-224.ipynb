# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-224' 
theme = 'Names where name parts are Modified'
category = 'Repetitions'
sub_category = '> 2 letters repeated once'
entity_type = 'Entity'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == '-0- ')] # only evaluate entities

# %% [markdown]
# ## randomly choose 10 rows

# %%
while True:
    ofac_list_sampled = ofac_list_filtered.sample(n = 10)
    cnt = [0] * 10
    for ind, name in enumerate(ofac_list_sampled['name']):
        split_name = name.upper().split(' ')
        
        for i in split_name:
            if all(j not in alphabet() for j in i):
                split_name.remove(i) # remove word with all numbers
                
        cnt[ind] += len(split_name)

    if all(i > 2 for i in cnt):
        break

ofac_list_sampled
# Out:
#         uid                                            name entity_type
# 992    8859           MOVEMENT FOR ISLAMIC REFORM IN ARABIA        -0-
# 3245  15953                     NOURI PETROCHEMICAL COMPANY        -0-
# 6807  26324             ZHENG DRUG TRAFFICKING ORGANIZATION        -0-
# 6885  26532                              ZAGROS PARDIS KISH        -0-
# 6064  24678  SOLUCIONES ELECTRICAS Y MECANICAS HADOM S.R.L.        -0-
# 7993  29865                         GOLDEN STAR TRADING LLC        -0-
# 8948  33998                         ROBNA KUCA METAL D.O.O.        -0-
# 8892  33879                            DOO BABUDOVAC BRNJAK        -0-
# 2355  12530                    AUTODROMO CULIACAN RACE PARK        -0-
# 84     4690                             ARMED ISLAMIC GROUP        -0-

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    split_original_name = original_name.split(' ') # split name into word
    final_test_name = split_original_name.copy()
    
    for i in split_original_name:
        if all(j not in alphabet() for j in i):
            split_original_name.remove(i) # remove word with all numbers
    
    if len(split_original_name) == 3:
        loop_time = 3
    else:
        loop_time = np.random.randint(3, len(split_original_name))
        
    for i in range(loop_time):
        replace_word = np.random.choice(split_original_name) # randomly choose word to be replaced
        split_original_name.remove(replace_word) # remove chosen word
        
        replace_word_list = list(replace_word)
        repeat_list = [] # get index of alphabets in each word
        for i in range(len(replace_word)):
            if replace_word[i] in alphabet():
                repeat_list.append(i)
        
        random_index = np.random.choice(repeat_list) # randomly choose letter to be repeated
        
        replace_word_list[random_index] += replace_word_list[random_index] # add repeated letter
        
        final_test_name[final_test_name.index(replace_word)] = ''.join(replace_word_list)

    final_test_name = ' '.join(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme     Category  \
# 0  UID-224  Names where name parts are Modified  Repetitions
# 1  UID-224  Names where name parts are Modified  Repetitions
# 2  UID-224  Names where name parts are Modified  Repetitions
# 3  UID-224  Names where name parts are Modified  Repetitions
# 4  UID-224  Names where name parts are Modified  Repetitions
# 5  UID-224  Names where name parts are Modified  Repetitions
# 6  UID-224  Names where name parts are Modified  Repetitions
# 7  UID-224  Names where name parts are Modified  Repetitions
# 8  UID-224  Names where name parts are Modified  Repetitions
# 9  UID-224  Names where name parts are Modified  Repetitions
#
#                 Sub-category Entity-Type    Test Case ID OFAC List UID  \
# 0  > 2 letters repeated once      Entity   UID-224 - 992          8859
# 1  > 2 letters repeated once      Entity  UID-224 - 3245         15953
# 2  > 2 letters repeated once      Entity  UID-224 - 6807         26324
# 3  > 2 letters repeated once      Entity  UID-224 - 6885         26532
# 4  > 2 letters repeated once      Entity  UID-224 - 6064         24678
# 5  > 2 letters repeated once      Entity  UID-224 - 7993         29865
# 6  > 2 letters repeated once      Entity  UID-224 - 8948         33998
# 7  > 2 letters repeated once      Entity  UID-224 - 8892         33879
# 8  > 2 letters repeated once      Entity  UID-224 - 2355         12530
# 9  > 2 letters repeated once      Entity    UID-224 - 84          4690
#
#                                     Original Name  \
# 0           MOVEMENT FOR ISLAMIC REFORM IN ARABIA
# 1                     NOURI PETROCHEMICAL COMPANY
# 2             ZHENG DRUG TRAFFICKING ORGANIZATION
# 3                              ZAGROS PARDIS KISH
# 4  SOLUCIONES ELECTRICAS Y MECANICAS HADOM S.R.L.
# 5                         GOLDEN STAR TRADING LLC
# 6                         ROBNA KUCA METAL D.O.O.
# 7                            DOO BABUDOVAC BRNJAK
# 8                    AUTODROMO CULIACAN RACE PARK
# 9                             ARMED ISLAMIC GROUP
#
#                                       Test Case Name
# 0           MOVEMENNT FOR ISLAMIC REFORRM IN AARABIA
# 1                     NOUURI PETROCHEEMICAL COOMPANY
# 2             ZZHENG DRUUG TRAFFICKING ORGANIZATIOON
# 3                              ZAAGROS PARDISS KISHH
# 4  SOLUCIONESS ELECTRICCAS YY MECANICAS HADOM SS....
# 5                         GOLDENN SSTAR TRADINNG LLC
# 6                         ROBBNA KUCA MEETAL D.O.OO.
# 7                            DOOO BABUDOVVAC BBRNJAK
# 8                    AUTODROMO CULIACAAN RACEE PAARK
# 9                             ARMMED ISSLAMIC GROUUP
