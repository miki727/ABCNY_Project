# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-276' 
theme = 'Names where name parts are Modified'
category = 'Truncation'
sub_category = '1 Letters Truncation in the front'
entity_type = 'Entity'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == '-0- ')] # only evaluate entities

# %% [markdown]
# ## randomly choose 10 rows

# %%
while True:
    ofac_list_sampled = ofac_list_filtered.sample(n = 10)
    cnt = [0] * 10
    for ind, name in enumerate(ofac_list_sampled['name']):
        split_name = name.upper().split(' ')
        
        if all(i in alphabet() for i in list(split_name[0][:1])) & (len(split_name[0]) > 1) & (len(' '.join(split_name)) > 10):
            cnt[ind] += 1

    if all(i == 1 for i in cnt):
        break

ofac_list_sampled
# Out:
#          uid                                      name entity_type
# 3386   16319                               CEC LIMITED        -0-
# 7441   28050              TRY PHEAP PROPERTY CO., LTD.        -0-
# 243     7146                ULSTER DEFENCE ASSOCIATION        -0-
# 143     6680              SERVIAUTOS UNO A 1A LIMITADA        -0-
# 2442   12743  SYRIAN MILITARY INTELLIGENCE DIRECTORATE        -0-
# 4287   19100                    LORD'S RESISTANCE ARMY        -0-
# 4529   20199                      OOO SHIPYARD 'ZALIV'        -0-
# 2355   12530              AUTODROMO CULIACAN RACE PARK        -0-
# 10456  37442        SCF MANAGEMENT SERVICES CYPRUS LTD        -0-
# 8032   30088                TOUMEH INTERNATIONAL GROUP        -0-

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    split_original_name = original_name.split(' ') # split name into word
    final_test_name = split_original_name.copy()
    
    truncate_word = split_original_name[0] # choose word to be truncated
        
    final_test_name[final_test_name.index(truncate_word)] = truncate_word[1:]

    final_test_name = ' '.join(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme    Category  \
# 0  UID-276  Names where name parts are Modified  Truncation
# 1  UID-276  Names where name parts are Modified  Truncation
# 2  UID-276  Names where name parts are Modified  Truncation
# 3  UID-276  Names where name parts are Modified  Truncation
# 4  UID-276  Names where name parts are Modified  Truncation
# 5  UID-276  Names where name parts are Modified  Truncation
# 6  UID-276  Names where name parts are Modified  Truncation
# 7  UID-276  Names where name parts are Modified  Truncation
# 8  UID-276  Names where name parts are Modified  Truncation
# 9  UID-276  Names where name parts are Modified  Truncation
#
#                         Sub-category Entity-Type     Test Case ID  \
# 0  1 Letters Truncation in the front      Entity   UID-276 - 3386
# 1  1 Letters Truncation in the front      Entity   UID-276 - 7441
# 2  1 Letters Truncation in the front      Entity    UID-276 - 243
# 3  1 Letters Truncation in the front      Entity    UID-276 - 143
# 4  1 Letters Truncation in the front      Entity   UID-276 - 2442
# 5  1 Letters Truncation in the front      Entity   UID-276 - 4287
# 6  1 Letters Truncation in the front      Entity   UID-276 - 4529
# 7  1 Letters Truncation in the front      Entity   UID-276 - 2355
# 8  1 Letters Truncation in the front      Entity  UID-276 - 10456
# 9  1 Letters Truncation in the front      Entity   UID-276 - 8032
#
#   OFAC List UID                             Original Name  \
# 0         16319                               CEC LIMITED
# 1         28050              TRY PHEAP PROPERTY CO., LTD.
# 2          7146                ULSTER DEFENCE ASSOCIATION
# 3          6680              SERVIAUTOS UNO A 1A LIMITADA
# 4         12743  SYRIAN MILITARY INTELLIGENCE DIRECTORATE
# 5         19100                    LORD'S RESISTANCE ARMY
# 6         20199                      OOO SHIPYARD 'ZALIV'
# 7         12530              AUTODROMO CULIACAN RACE PARK
# 8         37442        SCF MANAGEMENT SERVICES CYPRUS LTD
# 9         30088                TOUMEH INTERNATIONAL GROUP
#
#                             Test Case Name
# 0                               EC LIMITED
# 1              RY PHEAP PROPERTY CO., LTD.
# 2                LSTER DEFENCE ASSOCIATION
# 3              ERVIAUTOS UNO A 1A LIMITADA
# 4  YRIAN MILITARY INTELLIGENCE DIRECTORATE
# 5                    ORD'S RESISTANCE ARMY
# 6                      OO SHIPYARD 'ZALIV'
# 7              UTODROMO CULIACAN RACE PARK
# 8        CF MANAGEMENT SERVICES CYPRUS LTD
# 9                OUMEH INTERNATIONAL GROUP
