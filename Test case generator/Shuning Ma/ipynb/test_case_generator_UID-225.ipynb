# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-225' 
theme = 'Names where name parts are Modified'
category = 'Repetitions'
sub_category = '> 2 letters repeated once'
entity_type = 'Individual'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == 'individual')] # only evaluate entities

# %% [markdown]
# ## randomly choose 10 rows

# %%
while True:
    ofac_list_sampled = ofac_list_filtered.sample(n = 10)
    cnt = [0] * 10
    for ind, name in enumerate(ofac_list_sampled['name']):
        split_name = name.split(' ')
        
        for i in split_name:
            if all(j not in alphabet() for j in i):
                split_name.remove(i) # remove word with all numbers
                
        cnt[ind] += len(split_name)

    if all(i > 2 for i in cnt):
        break

ofac_list_sampled
# Out:
#         uid                                    name entity_type
# 303    7215                QUINTANA ZORROZUA, Asier  individual
# 1194   9564     QUINTERO SANCLEMENTE, Ramon Alberto  individual
# 6851  26426  BERMUDEZ VALDERREY, Alberto Mirtiliano  individual
# 2302  12404                       AZHAR, Abdul Rauf  individual
# 5408  23008                           PAK, Chol Nam  individual
# 1140   9480          AL-SIBA'I, Hani Muhammad Yusuf  individual
# 9669  35652             KOROBOVA, Olga Vladimirovna  individual
# 4127  18630               JONES, Sally-Anne Frances  individual
# 9038  34396               VALDEZ RUIZ, Miguel Angel  individual
# 9658  35641                  KVITKA, Ivan Ivanovich  individual

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    split_original_name = original_name.split(' ') # split name into word
    final_test_name = split_original_name.copy()
    
    for i in split_original_name:
        if all(j not in alphabet() for j in i):
            split_original_name.remove(i) # remove word with all numbers
    
    if len(split_original_name) == 3:
        loop_time = 3
    else:
        loop_time = np.random.randint(3, len(split_original_name))
        
    for i in range(loop_time):
        replace_word = np.random.choice(split_original_name) # randomly choose word to be replaced
        split_original_name.remove(replace_word) # remove chosen word
        
        replace_word_list = list(replace_word)
        repeat_list = [] # get index of alphabets in each word
        for i in range(len(replace_word)):
            if replace_word[i] in alphabet():
                repeat_list.append(i)
        
        random_index = np.random.choice(repeat_list) # randomly choose letter to be repeated
        
        replace_word_list[random_index] += replace_word_list[random_index] # add repeated letter
        
        final_test_name[final_test_name.index(replace_word)] = ''.join(replace_word_list)

    final_test_name = ' '.join(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme     Category  \
# 0  UID-225  Names where name parts are Modified  Repetitions
# 1  UID-225  Names where name parts are Modified  Repetitions
# 2  UID-225  Names where name parts are Modified  Repetitions
# 3  UID-225  Names where name parts are Modified  Repetitions
# 4  UID-225  Names where name parts are Modified  Repetitions
# 5  UID-225  Names where name parts are Modified  Repetitions
# 6  UID-225  Names where name parts are Modified  Repetitions
# 7  UID-225  Names where name parts are Modified  Repetitions
# 8  UID-225  Names where name parts are Modified  Repetitions
# 9  UID-225  Names where name parts are Modified  Repetitions
#
#                 Sub-category Entity-Type    Test Case ID OFAC List UID  \
# 0  > 2 letters repeated once  Individual   UID-225 - 303          7215
# 1  > 2 letters repeated once  Individual  UID-225 - 1194          9564
# 2  > 2 letters repeated once  Individual  UID-225 - 6851         26426
# 3  > 2 letters repeated once  Individual  UID-225 - 2302         12404
# 4  > 2 letters repeated once  Individual  UID-225 - 5408         23008
# 5  > 2 letters repeated once  Individual  UID-225 - 1140          9480
# 6  > 2 letters repeated once  Individual  UID-225 - 9669         35652
# 7  > 2 letters repeated once  Individual  UID-225 - 4127         18630
# 8  > 2 letters repeated once  Individual  UID-225 - 9038         34396
# 9  > 2 letters repeated once  Individual  UID-225 - 9658         35641
#
#                             Original Name  \
# 0                QUINTANA ZORROZUA, Asier
# 1     QUINTERO SANCLEMENTE, Ramon Alberto
# 2  BERMUDEZ VALDERREY, Alberto Mirtiliano
# 3                       AZHAR, Abdul Rauf
# 4                           PAK, Chol Nam
# 5          AL-SIBA'I, Hani Muhammad Yusuf
# 6             KOROBOVA, Olga Vladimirovna
# 7               JONES, Sally-Anne Frances
# 8               VALDEZ RUIZ, Miguel Angel
# 9                  KVITKA, Ivan Ivanovich
#
#                               Test Case Name
# 0                QUUINTANA ZORROOZUA, ASIIER
# 1     QUINTEERO SANCCLEMENTE, RAMMON ALBERTO
# 2  BERMUDEZ VALDERRREY, ALBERRTO MIRTILLIANO
# 3                       AZHARR, ABDUUL RRAUF
# 4                           PPAK, CHOOL NAAM
# 5          AL-SIBAA'I, HAANI MUHAMMMAD YUSUF
# 6             KOROBBOVA, OLGAA VLADIMIIROVNA
# 7               JONESS, SALLLY-ANNE FRANCCES
# 8               VVALDEZ RUIZ, MIGUEEL ANGEEL
# 9                  KVIITKA, IVAAN IVANOOVICH
