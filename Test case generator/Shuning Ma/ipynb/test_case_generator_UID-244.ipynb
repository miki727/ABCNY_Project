# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-244' 
theme = 'Names where name parts are Modified'
category = 'Transpositions'
sub_category = '> 2 transpositions (different name part)'
entity_type = 'Individual'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == 'individual')] # only evaluate individuals

# %% [markdown]
# ## randomly choose 10 rows

# %%
while True:
    ofac_list_sampled = ofac_list_filtered.sample(n = 10)
    cnt = [0] * 10
    for ind, name in enumerate(ofac_list_sampled['name']):
        split_name = name.upper().split(' ')
        
        for i in split_name:
            if all(j not in alphabet() for j in i):
                split_name.remove(i) # remove word with all numbers
            elif len(i) == 1:
                split_name.remove(i) # remove word with only 1 letter
                
        cnt[ind] += len(split_name)

    if all(i > 2 for i in cnt):
        break

ofac_list_sampled
# Out:
#         uid                                name entity_type
# 1310  10051                 KAZAN, Ali Muhammad  individual
# 7403  28003       AZARI JAHROMI, Mohammad Javad  individual
# 8703  32712        BUNAKOV, Andrei Nikolayevich  individual
# 4559  20251            LOPEZ BELLO, Samark Jose  individual
# 828    8251     ZEVALLOS GONZALES, Lupe Maritza  individual
# 7920  29787               PUREBRAHIM, Ali Akbar  individual
# 9635  35618      ZAKHAROV, Konstantin Yuryevich  individual
# 5335  22746      ZERPA DELGADO, Simon Alejandro  individual
# 2983  15520  AL-HARBI, Adel Radi Saqr Al-Wahabi  individual
# 2482  12843               ABD AL-RAHMAN, Atiyah  individual

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    split_original_name = original_name.split(' ') # split name into word
    final_test_name = split_original_name.copy()
    
    for i in split_original_name:
        if all(j not in alphabet() for j in i):
            split_original_name.remove(i) # remove word with all numbers
        elif len(i) == 1:
            split_original_name.remove(i) # remove word with only 1 letter
    
    if len(split_original_name) == 3:
        loop_time = 3
    else:
        loop_time = np.random.randint(3, len(split_original_name))
        
    for i in range(loop_time):
        replace_word = np.random.choice(split_original_name) # randomly choose word to be transposed
        split_original_name.remove(replace_word) # remove chosen word
        
        random_list = list(range(len(replace_word))) # randomly choose letter to be transposed
        while True:
            random_letter_index = np.random.choice(random_list)
            random_letter = replace_word[random_letter_index]
            if random_letter in alphabet():
                break
        random_list.remove(random_letter_index) # remove chosen letter index
        
        random_place = np.random.choice(random_list) # randomly choose place to transpose to
        
        replace_word_list = list(replace_word)
        del replace_word_list[random_letter_index] # remove chosen letter
        replace_word_list.insert(random_place, random_letter) # add transposed letter
        
        final_test_name[final_test_name.index(replace_word)] = ''.join(replace_word_list)

    final_test_name = ' '.join(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme        Category  \
# 0  UID-244  Names where name parts are Modified  Transpositions
# 1  UID-244  Names where name parts are Modified  Transpositions
# 2  UID-244  Names where name parts are Modified  Transpositions
# 3  UID-244  Names where name parts are Modified  Transpositions
# 4  UID-244  Names where name parts are Modified  Transpositions
# 5  UID-244  Names where name parts are Modified  Transpositions
# 6  UID-244  Names where name parts are Modified  Transpositions
# 7  UID-244  Names where name parts are Modified  Transpositions
# 8  UID-244  Names where name parts are Modified  Transpositions
# 9  UID-244  Names where name parts are Modified  Transpositions
#
#                                Sub-category Entity-Type    Test Case ID  \
# 0  > 2 transpositions (different name part)  Individual  UID-244 - 1310
# 1  > 2 transpositions (different name part)  Individual  UID-244 - 7403
# 2  > 2 transpositions (different name part)  Individual  UID-244 - 8703
# 3  > 2 transpositions (different name part)  Individual  UID-244 - 4559
# 4  > 2 transpositions (different name part)  Individual   UID-244 - 828
# 5  > 2 transpositions (different name part)  Individual  UID-244 - 7920
# 6  > 2 transpositions (different name part)  Individual  UID-244 - 9635
# 7  > 2 transpositions (different name part)  Individual  UID-244 - 5335
# 8  > 2 transpositions (different name part)  Individual  UID-244 - 2983
# 9  > 2 transpositions (different name part)  Individual  UID-244 - 2482
#
#   OFAC List UID                       Original Name  \
# 0         10051                 KAZAN, Ali Muhammad
# 1         28003       AZARI JAHROMI, Mohammad Javad
# 2         32712        BUNAKOV, Andrei Nikolayevich
# 3         20251            LOPEZ BELLO, Samark Jose
# 4          8251     ZEVALLOS GONZALES, Lupe Maritza
# 5         29787               PUREBRAHIM, Ali Akbar
# 6         35618      ZAKHAROV, Konstantin Yuryevich
# 7         22746      ZERPA DELGADO, Simon Alejandro
# 8         15520  AL-HARBI, Adel Radi Saqr Al-Wahabi
# 9         12843               ABD AL-RAHMAN, Atiyah
#
#                        Test Case Name
# 0                 AZAN,K AIL MUHMMAAD
# 1       AZIAR AHROMIJ, MOHAMMAD AVADJ
# 2        BUNAOV,K AINDRE NIKOLAYCEVIH
# 3            LEOPZ BELLO, SRAMAK JSOE
# 4     SZEVALLO GONZEALS, ULPE MARITZA
# 5               HPUREBRAIM, AIL KBARA
# 6      ZAHAROVK, KAONSTNTIN IYURYEVCH
# 7      ZEPAR DLGAEDO, SIMON JALEANDRO
# 8  AL-HABI,R ADEL ARDI SAQR AL-WHAABI
# 9               BAD AML-RAHAN, TAIYAH
