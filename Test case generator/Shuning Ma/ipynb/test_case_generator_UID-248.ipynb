# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet, num_of_alphabet

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-248' 
theme = 'Names where name parts are Modified'
category = 'Transpositions'
sub_category = '1 transposition - 2 letters at the beginning'
entity_type = 'Entity'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == '-0- ')] # only evaluate entities

# %% [markdown]
# ## randomly choose 10 rows

# %%
while True:
    ofac_list_sampled = ofac_list_filtered.sample(n = 10)
    cnt = [0] * 10
    for ind, name in enumerate(ofac_list_sampled['name']):
        split_name = name.split(' ')
        
        if all(i in alphabet() for i in list(split_name[0][:2])) & (len(split_name[0]) >= 2):
            cnt[ind] += 1

    if all(i == 1 for i in cnt):
        break

ofac_list_sampled
# Out:
#         uid                                               name entity_type
# 6580  25856                          UNIVERSE SHIPPING LIMITED        -0-
# 3793  17243                                    INDUSTRIAL BANK        -0-
# 3296  16020                              IRAN & SHARGH COMPANY        -0-
# 3299  16023                     ZARIN RAFSANJAN CEMENT COMPANY        -0-
# 3737  17099                            KARNER D.O.O. LJUBLJANA        -0-
# 1716  11167                SURAQIYA FOR MEDIA AND BROADCASTING        -0-
# 8999  34113  FUTURE GATE FUEL AND PETROCHEMICAL TRADING L.L.C.        -0-
# 1228   9618                                           KOHAS AG        -0-
# 9290  35082                                    OOO ROBIN TREID        -0-
# 9797  35867  JOINT STOCK COMPANY AZOVSKI OPTIKO MECHANICHES...        -0-

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    split_original_name = original_name.split(' ') # split name into word
    final_test_name = split_original_name.copy()
    
    for i in split_original_name:
        if all(j not in alphabet() for j in i):
            split_original_name.remove(i) # remove word with all numbers
        elif num_of_alphabet(i) < 2:
            split_original_name.remove(i) # remove word with less than 2 alphabets
        
    replace_word = split_original_name[0] # choose word to be transposed

    replace_word_list = list(replace_word)
    replace_word_list.insert(0, replace_word_list.pop(1)) # transpose

    final_test_name[final_test_name.index(replace_word)] = ''.join(replace_word_list)

    final_test_name = ' '.join(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme        Category  \
# 0  UID-248  Names where name parts are Modified  Transpositions
# 1  UID-248  Names where name parts are Modified  Transpositions
# 2  UID-248  Names where name parts are Modified  Transpositions
# 3  UID-248  Names where name parts are Modified  Transpositions
# 4  UID-248  Names where name parts are Modified  Transpositions
# 5  UID-248  Names where name parts are Modified  Transpositions
# 6  UID-248  Names where name parts are Modified  Transpositions
# 7  UID-248  Names where name parts are Modified  Transpositions
# 8  UID-248  Names where name parts are Modified  Transpositions
# 9  UID-248  Names where name parts are Modified  Transpositions
#
#                                    Sub-category Entity-Type    Test Case ID  \
# 0  1 transposition - 2 letters at the beginning      Entity  UID-248 - 6580
# 1  1 transposition - 2 letters at the beginning      Entity  UID-248 - 3793
# 2  1 transposition - 2 letters at the beginning      Entity  UID-248 - 3296
# 3  1 transposition - 2 letters at the beginning      Entity  UID-248 - 3299
# 4  1 transposition - 2 letters at the beginning      Entity  UID-248 - 3737
# 5  1 transposition - 2 letters at the beginning      Entity  UID-248 - 1716
# 6  1 transposition - 2 letters at the beginning      Entity  UID-248 - 8999
# 7  1 transposition - 2 letters at the beginning      Entity  UID-248 - 1228
# 8  1 transposition - 2 letters at the beginning      Entity  UID-248 - 9290
# 9  1 transposition - 2 letters at the beginning      Entity  UID-248 - 9797
#
#   OFAC List UID                                      Original Name  \
# 0         25856                          UNIVERSE SHIPPING LIMITED
# 1         17243                                    INDUSTRIAL BANK
# 2         16020                              IRAN & SHARGH COMPANY
# 3         16023                     ZARIN RAFSANJAN CEMENT COMPANY
# 4         17099                            KARNER D.O.O. LJUBLJANA
# 5         11167                SURAQIYA FOR MEDIA AND BROADCASTING
# 6         34113  FUTURE GATE FUEL AND PETROCHEMICAL TRADING L.L.C.
# 7          9618                                           KOHAS AG
# 8         35082                                    OOO ROBIN TREID
# 9         35867  JOINT STOCK COMPANY AZOVSKI OPTIKO MECHANICHES...
#
#                                       Test Case Name
# 0                          NUIVERSE SHIPPING LIMITED
# 1                                    NIDUSTRIAL BANK
# 2                              RIAN & SHARGH COMPANY
# 3                     AZRIN RAFSANJAN CEMENT COMPANY
# 4                            AKRNER D.O.O. LJUBLJANA
# 5                USRAQIYA FOR MEDIA AND BROADCASTING
# 6  UFTURE GATE FUEL AND PETROCHEMICAL TRADING L.L.C.
# 7                                           OKHAS AG
# 8                                    OOO ROBIN TREID
# 9  OJINT STOCK COMPANY AZOVSKI OPTIKO MECHANICHES...
