# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-227' 
theme = 'Names where name parts are Modified'
category = 'Repetitions'
sub_category = '> 2 letters repeated twice'
entity_type = 'Individual'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == 'individual')] # only evaluate individuals

# %% [markdown]
# ## randomly choose 10 rows

# %%
while True:
    ofac_list_sampled = ofac_list_filtered.sample(n = 10)
    cnt = [0] * 10
    for ind, name in enumerate(ofac_list_sampled['name']):
        split_name = name.split(' ')
        
        for i in split_name:
            if all(j not in alphabet() for j in i):
                split_name.remove(i) # remove word with all numbers
                
        cnt[ind] += len(split_name)

    if all(i > 2 for i in cnt):
        break

ofac_list_sampled
# Out:
#          uid                            name entity_type
# 9258   35026  YERSHOV, Sergey Aleksandrovich  individual
# 9292   35084      TOKAREV, Nikolay Petrovich  individual
# 10802  38856  SKOROBOGATOVA, Olga Nikolaevna  individual
# 7937   29806         MAGHSOUDI, Hassan Fazli  individual
# 9658   35641          KVITKA, Ivan Ivanovich  individual
# 10450  37430   ABDALLAH, Hussein Ahmad Jalal  individual
# 9857   35969    KLYUKIN, Mikhail Vasilyevich  individual
# 6133   24997                     RI, Song Un  individual
# 389     7493    GOCHE, Nicholas Tasunungurwa  individual
# 7942   29811       BABAIE, Nematollah Hosein  individual

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    split_original_name = original_name.split(' ') # split name into word
    final_test_name = split_original_name.copy()
    
    for i in split_original_name:
        if all(j not in alphabet() for j in i):
            split_original_name.remove(i) # remove word with all numbers
    
    if len(split_original_name) == 3:
        loop_time = 3
    else:
        loop_time = np.random.randint(3, len(split_original_name))
        
    for i in range(loop_time):
        replace_word = np.random.choice(split_original_name) # randomly choose word to be replaced
        split_original_name.remove(replace_word) # remove chosen word
        
        replace_word_list = list(replace_word)
        repeat_list = [] # get index of alphabets in each word
        for i in range(len(replace_word)):
            if replace_word[i] in alphabet():
                repeat_list.append(i)
        
        random_index = np.random.choice(repeat_list) # randomly choose letter to be repeated
        
        replace_word_list[random_index] += replace_word_list[random_index] + replace_word_list[random_index] # add repeated letter twice
        
        final_test_name[final_test_name.index(replace_word)] = ''.join(replace_word_list)

    final_test_name = ' '.join(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme     Category  \
# 0  UID-227  Names where name parts are Modified  Repetitions
# 1  UID-227  Names where name parts are Modified  Repetitions
# 2  UID-227  Names where name parts are Modified  Repetitions
# 3  UID-227  Names where name parts are Modified  Repetitions
# 4  UID-227  Names where name parts are Modified  Repetitions
# 5  UID-227  Names where name parts are Modified  Repetitions
# 6  UID-227  Names where name parts are Modified  Repetitions
# 7  UID-227  Names where name parts are Modified  Repetitions
# 8  UID-227  Names where name parts are Modified  Repetitions
# 9  UID-227  Names where name parts are Modified  Repetitions
#
#                  Sub-category Entity-Type     Test Case ID OFAC List UID  \
# 0  > 2 letters repeated twice  Individual   UID-227 - 9258         35026
# 1  > 2 letters repeated twice  Individual   UID-227 - 9292         35084
# 2  > 2 letters repeated twice  Individual  UID-227 - 10802         38856
# 3  > 2 letters repeated twice  Individual   UID-227 - 7937         29806
# 4  > 2 letters repeated twice  Individual   UID-227 - 9658         35641
# 5  > 2 letters repeated twice  Individual  UID-227 - 10450         37430
# 6  > 2 letters repeated twice  Individual   UID-227 - 9857         35969
# 7  > 2 letters repeated twice  Individual   UID-227 - 6133         24997
# 8  > 2 letters repeated twice  Individual    UID-227 - 389          7493
# 9  > 2 letters repeated twice  Individual   UID-227 - 7942         29811
#
#                     Original Name                        Test Case Name
# 0  YERSHOV, Sergey Aleksandrovich  YYYERSHOV, SSSERGEY ALEKSANDRRROVICH
# 1      TOKAREV, Nikolay Petrovich      TOKARRREV, NIKOLAYYY PEEETROVICH
# 2  SKOROBOGATOVA, Olga Nikolaevna  SKORRROBOGATOVA, OOOLGA NIKOLAEVVVNA
# 3         MAGHSOUDI, Hassan Fazli         MAGHSOUDIII, HASSANNN FAZLLLI
# 4          KVITKA, Ivan Ivanovich          KKKVITKA, IVVVAN IVANOVIIICH
# 5   ABDALLAH, Hussein Ahmad Jalal   ABDALLAH, HUSSEIIIN AHMAAAD JALAAAL
# 6    KLYUKIN, Mikhail Vasilyevich    KLLLYUKIN, MIIIKHAIL VASILYEEEVICH
# 7                     RI, Song Un                     RRRI, SSSONG UNNN
# 8    GOCHE, Nicholas Tasunungurwa    GOCHHHE, NICHOOOLAS TASUNUUUNGURWA
# 9       BABAIE, Nematollah Hosein       BBBABAIE, NEMATOLLLLAH HHHOSEIN
