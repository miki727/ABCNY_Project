# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-269' 
theme = 'Names where name parts are Modified'
category = 'Truncation'
sub_category = '> 2 Letters Truncation in the front'
entity_type = 'Entity'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == '-0- ')] # only evaluate entities

# %% [markdown]
# ## randomly choose 10 rows

# %%
while True:
    ofac_list_sampled = ofac_list_filtered.sample(n = 10)
    cnt = [0] * 10
    for ind, name in enumerate(ofac_list_sampled['name']):
        split_name = name.upper().split(' ')
        
        if all(i in alphabet() for i in list(split_name[0][:3])) & (len(split_name[0]) > 3) & (len(' '.join(split_name)) > 10):
            cnt[ind] += 1

    if all(i == 1 for i in cnt):
        break

ofac_list_sampled
# Out:
#         uid                                               name entity_type
# 823    8244                                AERO CONTINENTE S.A        -0-
# 2018  11772                       SERVIAGRICOLA CIFUENTES E.U.        -0-
# 5745  23665                             BLUE LAGOON GROUP LTD.        -0-
# 4754  21090                      EVENTOS LA MORA, S.A. DE C.V.        -0-
# 2202  12101  COMERCIALIZADORA DE GANADO Y RENTAS DE CAPITAL...        -0-
# 166    6730                                HAPPY DAYS S. DE H.        -0-
# 6736  26151                                       SUPLINKA SRL        -0-
# 9815  35885  JOINT STOCK COMPANY RYAZANSKOE KONSTRUKTORSKOE...        -0-
# 9875  36005                            SAYEHBAN SEPEHR DELIJAN        -0-
# 5272  22487               STATE BANK LUHANSK PEOPLE'S REPUBLIC        -0-

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    split_original_name = original_name.split(' ') # split name into word
    final_test_name = split_original_name.copy()
    
    truncate_word = split_original_name[0] # choose word to be truncated
    truncate_number = np.random.randint(3, len(truncate_word))
        
    final_test_name[final_test_name.index(truncate_word)] = truncate_word[truncate_number:]

    final_test_name = ' '.join(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme    Category  \
# 0  UID-269  Names where name parts are Modified  Truncation
# 1  UID-269  Names where name parts are Modified  Truncation
# 2  UID-269  Names where name parts are Modified  Truncation
# 3  UID-269  Names where name parts are Modified  Truncation
# 4  UID-269  Names where name parts are Modified  Truncation
# 5  UID-269  Names where name parts are Modified  Truncation
# 6  UID-269  Names where name parts are Modified  Truncation
# 7  UID-269  Names where name parts are Modified  Truncation
# 8  UID-269  Names where name parts are Modified  Truncation
# 9  UID-269  Names where name parts are Modified  Truncation
#
#                           Sub-category Entity-Type    Test Case ID  \
# 0  > 2 Letters Truncation in the front      Entity   UID-269 - 823
# 1  > 2 Letters Truncation in the front      Entity  UID-269 - 2018
# 2  > 2 Letters Truncation in the front      Entity  UID-269 - 5745
# 3  > 2 Letters Truncation in the front      Entity  UID-269 - 4754
# 4  > 2 Letters Truncation in the front      Entity  UID-269 - 2202
# 5  > 2 Letters Truncation in the front      Entity   UID-269 - 166
# 6  > 2 Letters Truncation in the front      Entity  UID-269 - 6736
# 7  > 2 Letters Truncation in the front      Entity  UID-269 - 9815
# 8  > 2 Letters Truncation in the front      Entity  UID-269 - 9875
# 9  > 2 Letters Truncation in the front      Entity  UID-269 - 5272
#
#   OFAC List UID                                      Original Name  \
# 0          8244                                AERO CONTINENTE S.A
# 1         11772                       SERVIAGRICOLA CIFUENTES E.U.
# 2         23665                             BLUE LAGOON GROUP LTD.
# 3         21090                      EVENTOS LA MORA, S.A. DE C.V.
# 4         12101  COMERCIALIZADORA DE GANADO Y RENTAS DE CAPITAL...
# 5          6730                                HAPPY DAYS S. DE H.
# 6         26151                                       SUPLINKA SRL
# 7         35885  JOINT STOCK COMPANY RYAZANSKOE KONSTRUKTORSKOE...
# 8         36005                            SAYEHBAN SEPEHR DELIJAN
# 9         22487               STATE BANK LUHANSK PEOPLE'S REPUBLIC
#
#                                       Test Case Name
# 0                                   O CONTINENTE S.A
# 1                           IAGRICOLA CIFUENTES E.U.
# 2                                E LAGOON GROUP LTD.
# 3                          TOS LA MORA, S.A. DE C.V.
# 4             ORA DE GANADO Y RENTAS DE CAPITAL S.A.
# 5                                    Y DAYS S. DE H.
# 6                                              A SRL
# 7  NT STOCK COMPANY RYAZANSKOE KONSTRUKTORSKOE BJ...
# 8                                   N SEPEHR DELIJAN
# 9                   E BANK LUHANSK PEOPLE'S REPUBLIC
