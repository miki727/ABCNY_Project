# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet, num_of_alphabet, rand_letter

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-312' 
theme = 'Names where name parts are Modified'
category = 'Typos'
sub_category = '2 Typos same name part - Non-adjacent'
entity_type = 'Entity'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == '-0- ')] # only evaluate entities

# %% [markdown]
# ## randomly choose 10 rows

# %%
while True:
    ofac_list_sampled = ofac_list_filtered.sample(n = 10)
    cnt = [0] * 10
    for ind, name in enumerate(ofac_list_sampled['name']):
        split_name = name.upper().split(' ')
        
        for i in split_name:     
            if num_of_alphabet(i) >= 4:
                cnt[ind] += 1
                break

    if all(i == 1 for i in cnt):
        break

ofac_list_sampled
# Out:
#         uid                                               name entity_type
# 5535  23256                       FLEURETTE PROPERTIES LIMITED        -0-
# 5889  24037        BARAKAT TRANSNATIONAL CRIMINAL ORGANIZATION        -0-
# 2074  11862                                       HERJEZ LTDA.        -0-
# 3110  15714                PROMESAS DEL FUTBOL COLOMBIANO S.A.        -0-
# 5688  23565  LIMITED LIABILITY COMPANY FOREIGN ECONOMIC ASS...        -0-
# 796    8213                                  AVIATRANS ANSTALT        -0-
# 890    8351             ATLAS AIR CONDITIONING COMPANY LIMITED        -0-
# 3302  16026             BEHSAZ KASHANE TEHRAN CONSTRUCTION CO.        -0-
# 8570  32065                                     BM SYSTEMS EAD        -0-
# 5542  23263                                  D.G.I. ISRAEL LTD        -0-

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    split_original_name = original_name.split(' ') # split name into word
    
    final_test_name = split_original_name.copy()
    
    split_edit_name = []
    for i in split_original_name:
        if not all(j not in alphabet() for j in i):
            split_edit_name.append(i) # remove word with all numbers
    
    while True:
        replace_word = np.random.choice(split_edit_name) # randomly choose word to be replaced
        if num_of_alphabet(replace_word) >= 4:
            break
    
    random_list = list(range(len(replace_word))) 
    replace_word_list = list(replace_word)

    if replace_word_list[-1] not in alphabet():
        del random_list[-3:]
    else:
        del random_list[-2:]
        
    rand_letter_index = np.random.choice(random_list) # randomly choose beginning letter to be replaced

    for i in range(0, 3, 2):
        while replace_word_list[rand_letter_index + i] == replace_word[rand_letter_index + i]: # rerandom if no letter has been replaced
            replace_word_list[rand_letter_index + i] = rand_letter() # replace letter

    final_test_name[final_test_name.index(replace_word)] = ''.join(replace_word_list)
    
    final_test_name = ' '.join(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme Category  \
# 0  UID-312  Names where name parts are Modified    Typos
# 1  UID-312  Names where name parts are Modified    Typos
# 2  UID-312  Names where name parts are Modified    Typos
# 3  UID-312  Names where name parts are Modified    Typos
# 4  UID-312  Names where name parts are Modified    Typos
# 5  UID-312  Names where name parts are Modified    Typos
# 6  UID-312  Names where name parts are Modified    Typos
# 7  UID-312  Names where name parts are Modified    Typos
# 8  UID-312  Names where name parts are Modified    Typos
# 9  UID-312  Names where name parts are Modified    Typos
#
#                             Sub-category Entity-Type    Test Case ID  \
# 0  2 Typos same name part - Non-adjacent      Entity  UID-312 - 5535
# 1  2 Typos same name part - Non-adjacent      Entity  UID-312 - 5889
# 2  2 Typos same name part - Non-adjacent      Entity  UID-312 - 2074
# 3  2 Typos same name part - Non-adjacent      Entity  UID-312 - 3110
# 4  2 Typos same name part - Non-adjacent      Entity  UID-312 - 5688
# 5  2 Typos same name part - Non-adjacent      Entity   UID-312 - 796
# 6  2 Typos same name part - Non-adjacent      Entity   UID-312 - 890
# 7  2 Typos same name part - Non-adjacent      Entity  UID-312 - 3302
# 8  2 Typos same name part - Non-adjacent      Entity  UID-312 - 8570
# 9  2 Typos same name part - Non-adjacent      Entity  UID-312 - 5542
#
#   OFAC List UID                                      Original Name  \
# 0         23256                       FLEURETTE PROPERTIES LIMITED
# 1         24037        BARAKAT TRANSNATIONAL CRIMINAL ORGANIZATION
# 2         11862                                       HERJEZ LTDA.
# 3         15714                PROMESAS DEL FUTBOL COLOMBIANO S.A.
# 4         23565  LIMITED LIABILITY COMPANY FOREIGN ECONOMIC ASS...
# 5          8213                                  AVIATRANS ANSTALT
# 6          8351             ATLAS AIR CONDITIONING COMPANY LIMITED
# 7         16026             BEHSAZ KASHANE TEHRAN CONSTRUCTION CO.
# 8         32065                                     BM SYSTEMS EAD
# 9         23263                                  D.G.I. ISRAEL LTD
#
#                                       Test Case Name
# 0                       FLEURETTE PROPEVTGES LIMITED
# 1        BARAKAT TRANSNATIONAL CRBMSNAL ORGANIZATION
# 2                                       HERJEZ NTOA.
# 3                PROMESAS DEL FUTFOS COLOMBIANO S.A.
# 4  LIMITED LIABILITY COMPANY FSRMIGN ECONOMIC ASS...
# 5                                  AVIATRGNP ANSTALT
# 6             AELWS AIR CONDITIONING COMPANY LIMITED
# 7             BEHSAZ KASHANE TEHRAN CONSTIUKTION CO.
# 8                                     BM SYSCEQS EAD
# 9                                  D.G.I. ISRBEP LTD
