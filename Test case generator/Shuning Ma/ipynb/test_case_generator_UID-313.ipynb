# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet, num_of_alphabet, rand_letter

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-313' 
theme = 'Names where name parts are Modified'
category = 'Typos'
sub_category = '2 Typos same name part - Non-adjacent'
entity_type = 'Individual'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == 'individual')] # only evaluate individuals

# %% [markdown]
# ## randomly choose 10 rows

# %%
while True:
    ofac_list_sampled = ofac_list_filtered.sample(n = 10)
    cnt = [0] * 10
    for ind, name in enumerate(ofac_list_sampled['name']):
        split_name = name.upper().split(' ')
        
        for i in split_name:     
            if num_of_alphabet(i) >= 4:
                cnt[ind] += 1
                break

    if all(i == 1 for i in cnt):
        break

ofac_list_sampled
# Out:
#         uid                                 name entity_type
# 8336  30885           AHMED, Isma'il Fu'ad Rasul  individual
# 3026  15594                     ZAGARIA, Carmine  individual
# 5225  22258                DARWISH, Samir Sakhir  individual
# 7202  27159                       DEHGHAN, Hamed  individual
# 7416  28023  AL-ISSAWI, Khamis Farhan Al-Khanjar  individual
# 5732  23644              MWISSA, Guidon Shimiray  individual
# 3441  16460       VARON CADENA, Greilyn Fernando  individual
# 3460  16479                 KHATTALAH, Ahmed Abu  individual
# 8781  33133                          NOORI, Omid  individual
# 3421  16434            KAHVARIN, Iradj Mohammadi  individual

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    split_original_name = original_name.split(' ') # split name into word
    
    final_test_name = split_original_name.copy()
    
    split_edit_name = []
    for i in split_original_name:
        if not all(j not in alphabet() for j in i):
            split_edit_name.append(i) # remove word with all numbers
    
    while True:
        replace_word = np.random.choice(split_edit_name) # randomly choose word to be replaced
        if num_of_alphabet(replace_word) >= 4:
            break
    
    random_list = list(range(len(replace_word))) 
    replace_word_list = list(replace_word)

    if replace_word_list[-1] not in alphabet():
        del random_list[-3:]
    else:
        del random_list[-2:]
        
    rand_letter_index = np.random.choice(random_list) # randomly choose beginning letter to be replaced

    for i in range(0, 3, 2):
        while replace_word_list[rand_letter_index + i] == replace_word[rand_letter_index + i]: # rerandom if no letter has been replaced
            replace_word_list[rand_letter_index + i] = rand_letter() # replace letter

    final_test_name[final_test_name.index(replace_word)] = ''.join(replace_word_list)
    
    final_test_name = ' '.join(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme Category  \
# 0  UID-313  Names where name parts are Modified    Typos
# 1  UID-313  Names where name parts are Modified    Typos
# 2  UID-313  Names where name parts are Modified    Typos
# 3  UID-313  Names where name parts are Modified    Typos
# 4  UID-313  Names where name parts are Modified    Typos
# 5  UID-313  Names where name parts are Modified    Typos
# 6  UID-313  Names where name parts are Modified    Typos
# 7  UID-313  Names where name parts are Modified    Typos
# 8  UID-313  Names where name parts are Modified    Typos
# 9  UID-313  Names where name parts are Modified    Typos
#
#                             Sub-category Entity-Type    Test Case ID  \
# 0  2 Typos same name part - Non-adjacent  Individual  UID-313 - 8336
# 1  2 Typos same name part - Non-adjacent  Individual  UID-313 - 3026
# 2  2 Typos same name part - Non-adjacent  Individual  UID-313 - 5225
# 3  2 Typos same name part - Non-adjacent  Individual  UID-313 - 7202
# 4  2 Typos same name part - Non-adjacent  Individual  UID-313 - 7416
# 5  2 Typos same name part - Non-adjacent  Individual  UID-313 - 5732
# 6  2 Typos same name part - Non-adjacent  Individual  UID-313 - 3441
# 7  2 Typos same name part - Non-adjacent  Individual  UID-313 - 3460
# 8  2 Typos same name part - Non-adjacent  Individual  UID-313 - 8781
# 9  2 Typos same name part - Non-adjacent  Individual  UID-313 - 3421
#
#   OFAC List UID                        Original Name  \
# 0         30885           AHMED, Isma'il Fu'ad Rasul
# 1         15594                     ZAGARIA, Carmine
# 2         22258                DARWISH, Samir Sakhir
# 3         27159                       DEHGHAN, Hamed
# 4         28023  AL-ISSAWI, Khamis Farhan Al-Khanjar
# 5         23644              MWISSA, Guidon Shimiray
# 6         16460       VARON CADENA, Greilyn Fernando
# 7         16479                 KHATTALAH, Ahmed Abu
# 8         33133                          NOORI, Omid
# 9         16434            KAHVARIN, Iradj Mohammadi
#
#                         Test Case Name
# 0           ATMJD, ISMA'IL FU'AD RASUL
# 1                     WAWARIA, CARMINE
# 2                DARWISH, SDMVR SAKHIR
# 3                       DEHGHAN, HFMMD
# 4  AL-ISSAWI, KHAMIS IAEHAN AL-KHANJAR
# 5              MWISSA, GUIUOQ SHIMIRAY
# 6       VARON CADENA, GRIIKYN FERNANDO
# 7                 KHAQTPLAH, AHMED ABU
# 8                          NOORI, PMKD
# 9            OAUVARIN, IRADJ MOHAMMADI
