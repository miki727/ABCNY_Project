# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-232' 
theme = 'Names where name parts are Modified'
category = 'Repetitions'
sub_category = '1 letters repeated twice'
entity_type = 'Entity'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == '-0- ')] # only evaluate entities

# %% [markdown]
# ## randomly choose 10 rows

# %%
ofac_list_sampled = ofac_list_filtered.sample(n = 10)
ofac_list_sampled
# Out:
#         uid                                      name entity_type
# 723    8109                AL-HARAMAIN : KENYA BRANCH        -0-
# 6350  25442                     BIIS MARITIME LIMITED        -0-
# 4052  18329      EBLA TRADE SERVICES S.A.L./OFF-SHORE        -0-
# 9829  35899  LIMITED LIABILITY COMPANY KAPO-AVTOTRANS        -0-
# 9237  35005                           LLC VEB SERVICE        -0-
# 2086  11880              AGUILAR AGUILAR Y CIA. LTDA.        -0-
# 47     1702                             PRENSA LATINA        -0-
# 1070   9350            SHAHID BAKERI INDUSTRIAL GROUP        -0-
# 2027  11792               FATER ENGINEERING INSTITUTE        -0-
# 32      815                   GALAX TRADING CO., LTD.        -0-

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    original_name_list = list(original_name) # transfer name string into letter list
    
    final_test_name = original_name_list.copy()
    
    repeat_list = [] # get index of alphabets in each name
    for i in range(len(original_name)):
        if original_name[i] in alphabet():
            repeat_list.append(i)
    
    random_index = np.random.choice(repeat_list) # randomly choose letter to be repeated
    repeat_list.remove(random_index) # remove chosen letter

    final_test_name[random_index] += original_name_list[random_index] + original_name_list[random_index] # add repeated letter twice

    final_test_name = ''.join(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme     Category  \
# 0  UID-232  Names where name parts are Modified  Repetitions
# 1  UID-232  Names where name parts are Modified  Repetitions
# 2  UID-232  Names where name parts are Modified  Repetitions
# 3  UID-232  Names where name parts are Modified  Repetitions
# 4  UID-232  Names where name parts are Modified  Repetitions
# 5  UID-232  Names where name parts are Modified  Repetitions
# 6  UID-232  Names where name parts are Modified  Repetitions
# 7  UID-232  Names where name parts are Modified  Repetitions
# 8  UID-232  Names where name parts are Modified  Repetitions
# 9  UID-232  Names where name parts are Modified  Repetitions
#
#                Sub-category Entity-Type    Test Case ID OFAC List UID  \
# 0  1 letters repeated twice      Entity   UID-232 - 723          8109
# 1  1 letters repeated twice      Entity  UID-232 - 6350         25442
# 2  1 letters repeated twice      Entity  UID-232 - 4052         18329
# 3  1 letters repeated twice      Entity  UID-232 - 9829         35899
# 4  1 letters repeated twice      Entity  UID-232 - 9237         35005
# 5  1 letters repeated twice      Entity  UID-232 - 2086         11880
# 6  1 letters repeated twice      Entity    UID-232 - 47          1702
# 7  1 letters repeated twice      Entity  UID-232 - 1070          9350
# 8  1 letters repeated twice      Entity  UID-232 - 2027         11792
# 9  1 letters repeated twice      Entity    UID-232 - 32           815
#
#                               Original Name  \
# 0                AL-HARAMAIN : KENYA BRANCH
# 1                     BIIS MARITIME LIMITED
# 2      EBLA TRADE SERVICES S.A.L./OFF-SHORE
# 3  LIMITED LIABILITY COMPANY KAPO-AVTOTRANS
# 4                           LLC VEB SERVICE
# 5              AGUILAR AGUILAR Y CIA. LTDA.
# 6                             PRENSA LATINA
# 7            SHAHID BAKERI INDUSTRIAL GROUP
# 8               FATER ENGINEERING INSTITUTE
# 9                   GALAX TRADING CO., LTD.
#
#                                Test Case Name
# 0                AL-HARAMAIN : KEEENYA BRANCH
# 1                     BIIS MARITIIIME LIMITED
# 2      EBLA TRADE SERVICES S.A.L./OFF-SHOREEE
# 3  LIMITED LIABILITY COMPANY KKKAPO-AVTOTRANS
# 4                           LLLLC VEB SERVICE
# 5              AGUILAR AGUILAR Y CIA. LTTTDA.
# 6                             PRRRENSA LATINA
# 7            SHAHID BAKERI INDUSSSTRIAL GROUP
# 8               FATER ENGINEERRRING INSTITUTE
# 9                   GALLLAX TRADING CO., LTD.
