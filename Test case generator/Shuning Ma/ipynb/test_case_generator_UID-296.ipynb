# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet, num_of_alphabet, rand_letter

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-296' 
theme = 'Names where name parts are Modified'
category = 'Typos'
sub_category = '> 2 Typos same name part - Non-adjacent'
entity_type = 'Entity'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == '-0- ')] # only evaluate entities

# %% [markdown]
# ## randomly choose 10 rows

# %%
while True:
    ofac_list_sampled = ofac_list_filtered.sample(n = 10)
    cnt = [0] * 10
    for ind, name in enumerate(ofac_list_sampled['name']):
        split_name = name.upper().split(' ')
        
        for i in split_name:     
            if num_of_alphabet(i) >= 6:
                cnt[ind] += 1
                break

    if all(i == 1 for i in cnt):
        break

ofac_list_sampled
# Out:
#         uid                                               name entity_type
# 9169  34769                          MINSK WHEEL TRACTOR PLANT        -0-
# 7857  29422                               ZAGROS PETROCHEMICAL        -0-
# 8550  32024                                  VABO SYSTEMS EOOD        -0-
# 2078  11868  EJERCITO REVOLUCIONARIO POPULAR ANTITERRORISTA...        -0-
# 2182  12028                                       ONERBANK ZAO        -0-
# 6598  25889                BEHSAZAN PARS EQUIPMENT DEVELOPMENT        -0-
# 7835  29299         XINJIANG PRODUCTION AND CONSTRUCTION CORPS        -0-
# 8632  32356                           SAYDNAYA MILITARY PRISON        -0-
# 2061  11842                             WISMOTOS FUENTE DE ORO        -0-
# 4508  20123               ORGANIZATION AND GUIDANCE DEPARTMENT        -0-

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    split_original_name = original_name.split(' ') # split name into word
    
    final_test_name = split_original_name.copy()
    
    split_edit_name = []
    for i in split_original_name:
        if not all(j not in alphabet() for j in i):
            split_edit_name.append(i) # remove word with all numbers
    
    while True:
        replace_word = np.random.choice(split_edit_name) # randomly choose word to be replaced
        if num_of_alphabet(replace_word) >= 6:
            break
    
    random_list = list(range(len(replace_word))) 
    replace_word_list = list(replace_word)

    if replace_word_list[-1] not in alphabet():
        del random_list[-5:]
    else:
        del random_list[-4:]
        
    rand_letter_index = np.random.choice(random_list) # randomly choose beginning letter to be replaced

    if len(replace_word_list) - rand_letter_index == 4:
        random_length = 4
    else:
        random_length = np.random.choice(list(range(4, len(replace_word_list) - rand_letter_index, 2)))

    for i in range(0, random_length + 1, 2):
        while replace_word_list[rand_letter_index + i] == replace_word[rand_letter_index + i]: # rerandom if no letter has been replaced
            replace_word_list[rand_letter_index + i] = rand_letter() # replace letter

    final_test_name[final_test_name.index(replace_word)] = ''.join(replace_word_list)
    
    final_test_name = ' '.join(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme Category  \
# 0  UID-296  Names where name parts are Modified    Typos
# 1  UID-296  Names where name parts are Modified    Typos
# 2  UID-296  Names where name parts are Modified    Typos
# 3  UID-296  Names where name parts are Modified    Typos
# 4  UID-296  Names where name parts are Modified    Typos
# 5  UID-296  Names where name parts are Modified    Typos
# 6  UID-296  Names where name parts are Modified    Typos
# 7  UID-296  Names where name parts are Modified    Typos
# 8  UID-296  Names where name parts are Modified    Typos
# 9  UID-296  Names where name parts are Modified    Typos
#
#                               Sub-category Entity-Type    Test Case ID  \
# 0  > 2 Typos same name part - Non-adjacent      Entity  UID-296 - 9169
# 1  > 2 Typos same name part - Non-adjacent      Entity  UID-296 - 7857
# 2  > 2 Typos same name part - Non-adjacent      Entity  UID-296 - 8550
# 3  > 2 Typos same name part - Non-adjacent      Entity  UID-296 - 2078
# 4  > 2 Typos same name part - Non-adjacent      Entity  UID-296 - 2182
# 5  > 2 Typos same name part - Non-adjacent      Entity  UID-296 - 6598
# 6  > 2 Typos same name part - Non-adjacent      Entity  UID-296 - 7835
# 7  > 2 Typos same name part - Non-adjacent      Entity  UID-296 - 8632
# 8  > 2 Typos same name part - Non-adjacent      Entity  UID-296 - 2061
# 9  > 2 Typos same name part - Non-adjacent      Entity  UID-296 - 4508
#
#   OFAC List UID                                      Original Name  \
# 0         34769                          MINSK WHEEL TRACTOR PLANT
# 1         29422                               ZAGROS PETROCHEMICAL
# 2         32024                                  VABO SYSTEMS EOOD
# 3         11868  EJERCITO REVOLUCIONARIO POPULAR ANTITERRORISTA...
# 4         12028                                       ONERBANK ZAO
# 5         25889                BEHSAZAN PARS EQUIPMENT DEVELOPMENT
# 6         29299         XINJIANG PRODUCTION AND CONSTRUCTION CORPS
# 7         32356                           SAYDNAYA MILITARY PRISON
# 8         11842                             WISMOTOS FUENTE DE ORO
# 9         20123               ORGANIZATION AND GUIDANCE DEPARTMENT
#
#                                       Test Case Name
# 0                          MINSK WHEEL TXAUTWR PLANT
# 1                               ZHGJOR PETROCHEMICAL
# 2                                  VABO SYYTNMB EOOD
# 3  EJIRUIBO REVOLUCIONARIO POPULAR ANTITERRORISTA...
# 4                                       OFEUBMNK ZAO
# 5                BUHLAMAH PARS EQUIPMENT DEVELOPMENT
# 6         XINJIANG PRODHCKIZN AND CONSTRUCTION CORPS
# 7                           SAYDNAYA MILITARY PGIVOU
# 8                             YIKMXTLS FUENTE DE ORO
# 9               OMGYNYZTTLOK AND GUIDANCE DEPARTMENT
