# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-235' 
theme = 'Names where name parts are Modified'
category = 'Repetitions'
sub_category = '2 letters repeated once'
entity_type = 'Entity'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == '-0- ')] # only evaluate entities

# %% [markdown]
# ## randomly choose 10 rows

# %%
while True:
    ofac_list_sampled = ofac_list_filtered.sample(n = 10)
    cnt = [0] * 10
    for ind, name in enumerate(ofac_list_sampled['name']):
        split_name = name.split(' ')
        
        for i in split_name:
            if all(j not in alphabet() for j in i):
                split_name.remove(i) # remove word with all numbers
                
        cnt[ind] += len(split_name)

    if all(i >= 2 for i in cnt):
        break

ofac_list_sampled
# Out:
#          uid                                               name entity_type
# 7050   26821                   KHOUZESTAN PETROCHEMICAL COMPANY        -0-
# 6562   25838                            NATIONWIDE SHIPPING LTD        -0-
# 5846   23899                         TECHNO TRANSPORTE ML, C.A.        -0-
# 6483   25629                                DAY LEASING COMPANY        -0-
# 5818   23803                                      ANSARUL ISLAM        -0-
# 10723  38218                                 DZHI AI INVEST OOO        -0-
# 346     7289                         INMOBILIARIA LINARES LTDA.        -0-
# 9080   34517  CENTER FOR SUPPORT AND DEVELOPMENT OF PUBLIC I...        -0-
# 2104   11913                      ISLAMIC NATIONAL BANK OF GAZA        -0-
# 1317   10100                                       JEHOVA LTDA.        -0-

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    split_original_name = original_name.split(' ') # split name into word
    final_test_name = split_original_name.copy()
    
    for i in split_original_name:
        if all(j not in alphabet() for j in i):
            split_original_name.remove(i) # remove word with all numbers
        
    for i in range(2):
        replace_word = np.random.choice(split_original_name) # randomly choose word to be replaced
        split_original_name.remove(replace_word) # remove chosen word
        
        replace_word_list = list(replace_word)
        repeat_list = [] # get index of alphabets in each word
        for i in range(len(replace_word)):
            if replace_word[i] in alphabet():
                repeat_list.append(i)
        
        random_index = np.random.choice(repeat_list) # randomly choose letter to be repeated
        
        replace_word_list[random_index] += replace_word_list[random_index] # add repeated letter
        
        final_test_name[final_test_name.index(replace_word)] = ''.join(replace_word_list)

    final_test_name = ' '.join(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme     Category  \
# 0  UID-235  Names where name parts are Modified  Repetitions
# 1  UID-235  Names where name parts are Modified  Repetitions
# 2  UID-235  Names where name parts are Modified  Repetitions
# 3  UID-235  Names where name parts are Modified  Repetitions
# 4  UID-235  Names where name parts are Modified  Repetitions
# 5  UID-235  Names where name parts are Modified  Repetitions
# 6  UID-235  Names where name parts are Modified  Repetitions
# 7  UID-235  Names where name parts are Modified  Repetitions
# 8  UID-235  Names where name parts are Modified  Repetitions
# 9  UID-235  Names where name parts are Modified  Repetitions
#
#               Sub-category Entity-Type     Test Case ID OFAC List UID  \
# 0  2 letters repeated once      Entity   UID-235 - 7050         26821
# 1  2 letters repeated once      Entity   UID-235 - 6562         25838
# 2  2 letters repeated once      Entity   UID-235 - 5846         23899
# 3  2 letters repeated once      Entity   UID-235 - 6483         25629
# 4  2 letters repeated once      Entity   UID-235 - 5818         23803
# 5  2 letters repeated once      Entity  UID-235 - 10723         38218
# 6  2 letters repeated once      Entity    UID-235 - 346          7289
# 7  2 letters repeated once      Entity   UID-235 - 9080         34517
# 8  2 letters repeated once      Entity   UID-235 - 2104         11913
# 9  2 letters repeated once      Entity   UID-235 - 1317         10100
#
#                                        Original Name  \
# 0                   KHOUZESTAN PETROCHEMICAL COMPANY
# 1                            NATIONWIDE SHIPPING LTD
# 2                         TECHNO TRANSPORTE ML, C.A.
# 3                                DAY LEASING COMPANY
# 4                                      ANSARUL ISLAM
# 5                                 DZHI AI INVEST OOO
# 6                         INMOBILIARIA LINARES LTDA.
# 7  CENTER FOR SUPPORT AND DEVELOPMENT OF PUBLIC I...
# 8                      ISLAMIC NATIONAL BANK OF GAZA
# 9                                       JEHOVA LTDA.
#
#                                       Test Case Name
# 0                 KHOOUZESTAN PETROCCHEMICAL COMPANY
# 1                          NATIONWWIDE SHIPPPING LTD
# 2                       TECHNO TRAANSPORTE MLL, C.A.
# 3                              DDAY LEASINGG COMPANY
# 4                                    ANSAARUL IISLAM
# 5                               DZHI AII INVEEST OOO
# 6                       INMOBILIARIAA LINARES LTDDA.
# 7  CENTER FFOR SUPPORT AAND DEVELOPMENT OF PUBLIC...
# 8                    ISLAMIC NATIONAL BAANK OFF GAZA
# 9                                     JEEHOVA LTDDA.
