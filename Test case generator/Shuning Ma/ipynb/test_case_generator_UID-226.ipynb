# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-226' 
theme = 'Names where name parts are Modified'
category = 'Repetitions'
sub_category = '> 2 letters repeated twice'
entity_type = 'Entity'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == '-0- ')] # only evaluate entities

# %% [markdown]
# ## randomly choose 10 rows

# %%
while True:
    ofac_list_sampled = ofac_list_filtered.sample(n = 10)
    cnt = [0] * 10
    for ind, name in enumerate(ofac_list_sampled['name']):
        split_name = name.split(' ')
        
        for i in split_name:
            if all(j not in alphabet() for j in i):
                split_name.remove(i) # remove word with all numbers
                
        cnt[ind] += len(split_name)

    if all(i > 2 for i in cnt):
        break

ofac_list_sampled
# Out:
#          uid                                               name entity_type
# 4753   21089  CIRCULO REPRESENTACIONES INTERNACIONALES, S. D...        -0-
# 10023  36429           JOINT STOCK COMPANY UNITED CREDIT BUREAU        -0-
# 10327  37197             JOINT STOCK COMPANY CHANNEL ONE RUSSIA        -0-
# 1381   10253                           OVERSEAS TRADING COMPANY        -0-
# 1014    8896    CORPORACION DE ALMACENES POR DEPARTAMENTOS S.A.        -0-
# 3352   16181        INMOBILIARIA RIVERA MARADIAGA, S.A. DE C.V.        -0-
# 335     7269                     GLOBAL RELIEF FOUNDATION, INC.        -0-
# 4313   19165                                PLAZA MILENIO, S.A.        -0-
# 5324   22697                   AJILY SOFTWARE PROCUREMENT GROUP        -0-
# 5749   23669                      GOLDEN FISH S.A.L. (OFFSHORE)        -0-

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    split_original_name = original_name.split(' ') # split name into word
    final_test_name = split_original_name.copy()
    
    for i in split_original_name:
        if all(j not in alphabet() for j in i):
            split_original_name.remove(i) # remove word with all numbers
    
    if len(split_original_name) == 3:
        loop_time = 3
    else:
        loop_time = np.random.randint(3, len(split_original_name))
        
    for i in range(loop_time):
        replace_word = np.random.choice(split_original_name) # randomly choose word to be replaced
        split_original_name.remove(replace_word) # remove chosen word
        
        replace_word_list = list(replace_word)
        repeat_list = [] # get index of alphabets in each word
        for i in range(len(replace_word)):
            if replace_word[i] in alphabet():
                repeat_list.append(i)
        
        random_index = np.random.choice(repeat_list) # randomly choose letter to be repeated
        
        replace_word_list[random_index] += replace_word_list[random_index] + replace_word_list[random_index] # add repeated letter twice
        
        final_test_name[final_test_name.index(replace_word)] = ''.join(replace_word_list)

    final_test_name = ' '.join(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme     Category  \
# 0  UID-226  Names where name parts are Modified  Repetitions
# 1  UID-226  Names where name parts are Modified  Repetitions
# 2  UID-226  Names where name parts are Modified  Repetitions
# 3  UID-226  Names where name parts are Modified  Repetitions
# 4  UID-226  Names where name parts are Modified  Repetitions
# 5  UID-226  Names where name parts are Modified  Repetitions
# 6  UID-226  Names where name parts are Modified  Repetitions
# 7  UID-226  Names where name parts are Modified  Repetitions
# 8  UID-226  Names where name parts are Modified  Repetitions
# 9  UID-226  Names where name parts are Modified  Repetitions
#
#                  Sub-category Entity-Type     Test Case ID OFAC List UID  \
# 0  > 2 letters repeated twice      Entity   UID-226 - 4753         21089
# 1  > 2 letters repeated twice      Entity  UID-226 - 10023         36429
# 2  > 2 letters repeated twice      Entity  UID-226 - 10327         37197
# 3  > 2 letters repeated twice      Entity   UID-226 - 1381         10253
# 4  > 2 letters repeated twice      Entity   UID-226 - 1014          8896
# 5  > 2 letters repeated twice      Entity   UID-226 - 3352         16181
# 6  > 2 letters repeated twice      Entity    UID-226 - 335          7269
# 7  > 2 letters repeated twice      Entity   UID-226 - 4313         19165
# 8  > 2 letters repeated twice      Entity   UID-226 - 5324         22697
# 9  > 2 letters repeated twice      Entity   UID-226 - 5749         23669
#
#                                        Original Name  \
# 0  CIRCULO REPRESENTACIONES INTERNACIONALES, S. D...
# 1           JOINT STOCK COMPANY UNITED CREDIT BUREAU
# 2             JOINT STOCK COMPANY CHANNEL ONE RUSSIA
# 3                           OVERSEAS TRADING COMPANY
# 4    CORPORACION DE ALMACENES POR DEPARTAMENTOS S.A.
# 5        INMOBILIARIA RIVERA MARADIAGA, S.A. DE C.V.
# 6                     GLOBAL RELIEF FOUNDATION, INC.
# 7                                PLAZA MILENIO, S.A.
# 8                   AJILY SOFTWARE PROCUREMENT GROUP
# 9                      GOLDEN FISH S.A.L. (OFFSHORE)
#
#                                       Test Case Name
# 0  CIRCULO REPRESENTACIONES INTERNNNACIONALES, SS...
# 1  JOIIINT STOCK COMPAAANY UUUNITED CREDIIIT BUUU...
# 2   JOINT STOCCCK COMPANYYY CHANNNNEL ONEEE RUSSIAAA
# 3                     OVERRRSEAS TRADIIING COMPAAANY
# 4  CORPORACCCION DEEE ALMACENES POR DEPARTAAAMENT...
# 5  INMOBILIARIA RIVERA MARADIAGA, S.AAA. DDDE CCC.V.
# 6               GLOBAL RELIEFFF FOUUUNDATION, INNNC.
# 7                          PLAZZZA MILLLENIO, S.AAA.
# 8             AAAJILY SOFTTTWARE PROCUREMENT GROUUUP
# 9                GOLDEN FISSSH S.AAA.L. (OFFSHORRRE)
