# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet, num_of_alphabet

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-280' 
theme = 'Names where name parts are Modified'
category = 'Truncation'
sub_category = '2 Letter Truncation in a middle name part'
entity_type = 'Individual'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == 'individual')] # only evaluate individuals

# %% [markdown]
# ## randomly choose 10 rows

# %%
while True:
    ofac_list_sampled = ofac_list_filtered.sample(n = 10)
    cnt = [0] * 10
    for ind, name in enumerate(ofac_list_sampled['name']):
        split_name = name.upper().split(' ')
        
        for i in split_name:
            if all(j not in alphabet() for j in i):
                split_name.remove(i) # remove word with all numbers
            elif len(i) < 3:
                split_name.remove(i) # remove word with < 3 letter
                
        cnt[ind] += len(split_name)

    if all(i > 2 for i in cnt):
        break

ofac_list_sampled
# Out:
#          uid                              name entity_type
# 10053  36500   RESHETNIKOV, Maxim Gennadyevich  individual
# 648     7876    AL-YASSIN, Husam Muhammad Amin  individual
# 6021   24541                KAREEM, Aras Habib  individual
# 1616   10726   AL MAZIDIH, Badran Turki Hishan  individual
# 5664   23516                    PAK, Kwang Hun  individual
# 911     8379                    JON, Hana Paul  individual
# 8512   31941                   SAING, Sai Lone  individual
# 8668   32496  MARRUFO CABRERA, Miguel Raymundo  individual
# 3181   15843            VILLA SANCHEZ, Arnoldo  individual
# 149     6708         CARRILLO FUENTES, Vicente  individual

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    split_original_name = original_name.split(' ') # split name into word
    final_test_name = split_original_name.copy()
    
    split_edit_name = []
    for i in split_original_name:
        if (not all(j not in alphabet() for j in i)) & (num_of_alphabet(i) > 2):
            split_edit_name.append(i) # remove word with all numbers # remove word with < 3 letter
    
    truncate_word = split_edit_name[len(split_edit_name) // 2] # choose word to be truncated
    truncate_number = 2
    if (truncate_word[-1] not in alphabet()) | (truncate_word[-2] not in alphabet()):
        truncate_number += 1
        
    final_test_name[final_test_name.index(truncate_word)] = truncate_word[:len(truncate_word) - truncate_number]

    final_test_name = ' '.join(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme    Category  \
# 0  UID-280  Names where name parts are Modified  Truncation
# 1  UID-280  Names where name parts are Modified  Truncation
# 2  UID-280  Names where name parts are Modified  Truncation
# 3  UID-280  Names where name parts are Modified  Truncation
# 4  UID-280  Names where name parts are Modified  Truncation
# 5  UID-280  Names where name parts are Modified  Truncation
# 6  UID-280  Names where name parts are Modified  Truncation
# 7  UID-280  Names where name parts are Modified  Truncation
# 8  UID-280  Names where name parts are Modified  Truncation
# 9  UID-280  Names where name parts are Modified  Truncation
#
#                                 Sub-category Entity-Type     Test Case ID  \
# 0  2 Letter Truncation in a middle name part  Individual  UID-280 - 10053
# 1  2 Letter Truncation in a middle name part  Individual    UID-280 - 648
# 2  2 Letter Truncation in a middle name part  Individual   UID-280 - 6021
# 3  2 Letter Truncation in a middle name part  Individual   UID-280 - 1616
# 4  2 Letter Truncation in a middle name part  Individual   UID-280 - 5664
# 5  2 Letter Truncation in a middle name part  Individual    UID-280 - 911
# 6  2 Letter Truncation in a middle name part  Individual   UID-280 - 8512
# 7  2 Letter Truncation in a middle name part  Individual   UID-280 - 8668
# 8  2 Letter Truncation in a middle name part  Individual   UID-280 - 3181
# 9  2 Letter Truncation in a middle name part  Individual    UID-280 - 149
#
#   OFAC List UID                     Original Name  \
# 0         36500   RESHETNIKOV, Maxim Gennadyevich
# 1          7876    AL-YASSIN, Husam Muhammad Amin
# 2         24541                KAREEM, Aras Habib
# 3         10726   AL MAZIDIH, Badran Turki Hishan
# 4         23516                    PAK, Kwang Hun
# 5          8379                    JON, Hana Paul
# 6         31941                   SAING, Sai Lone
# 7         32496  MARRUFO CABRERA, Miguel Raymundo
# 8         15843            VILLA SANCHEZ, Arnoldo
# 9          6708         CARRILLO FUENTES, Vicente
#
#                    Test Case Name
# 0   RESHETNIKOV, MAX GENNADYEVICH
# 1    AL-YASSIN, HUSAM MUHAMM AMIN
# 2                KAREEM, AR HABIB
# 3   AL MAZIDIH, BADRAN TUR HISHAN
# 4                    PAK, KWA HUN
# 5                    JON, HA PAUL
# 6                   SAING, S LONE
# 7  MARRUFO CABRERA, MIGU RAYMUNDO
# 8             VILLA SANCH ARNOLDO
# 9          CARRILLO FUENT VICENTE
