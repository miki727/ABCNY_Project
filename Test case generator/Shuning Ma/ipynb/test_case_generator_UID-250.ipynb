# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet, num_of_alphabet

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-250' 
theme = 'Names where name parts are Modified'
category = 'Transpositions'
sub_category = '1 transposition - more than 2 letters anywhere'
entity_type = 'Entity'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == '-0- ')] # only evaluate entities

# %% [markdown]
# ## randomly choose 10 rows

# %%
ofac_list_sampled = ofac_list_filtered.sample(n = 10)
ofac_list_sampled
# Out:
#          uid                                               name entity_type
# 10670  37901  TEO BOON CHING WILDLIFE TRAFFICKING TRANSNATIO...        -0-
# 3633   16860                                           TEMPBANK        -0-
# 7983   29853                              ATLAS SHIP MANAGEMENT        -0-
# 7741   29019                                   KALAI INDUSTRIES        -0-
# 8896   33883             ZARKO VESELINOVIC B.I., S.T.R. KRISTAL        -0-
# 90      4697                                          HIZBALLAH        -0-
# 8946   33996                          P.P.ROBNA KUCA METAL B.I.        -0-
# 3972   18093                    AHOME REAL ESTATE, S.A. DE C.V.        -0-
# 8426   31415  FEDERAL STATE AUTONOMOUS SCIENTIFIC ESTABLISHM...        -0-
# 3793   17243                                    INDUSTRIAL BANK        -0-

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    original_name_list = list(original_name) # transfer name string into letter list
    
    final_test_name = original_name_list.copy()
    
    if num_of_alphabet(original_name_list) == 3:
        loop_time = 3
    else:
        loop_time = np.random.randint(3, num_of_alphabet(original_name_list))
    
    while True:
        for i in range(loop_time):
            random_list = list(range(len(original_name_list))) # randomly choose letter to be transposed
            while True:
                random_letter_index = np.random.choice(random_list)
                random_letter = original_name_list[random_letter_index]
                if random_letter in alphabet():
                    break
            random_list.remove(random_letter_index) # remove chosen letter index

            random_place = np.random.choice(random_list) # randomly choose place to transpose to

            del original_name_list[random_letter_index] # remove chosen letter
            original_name_list.insert(random_place, random_letter) # add transposed letter

            final_test_name = ''.join(original_name_list)
            replace_word = ''.join(original_name_list)
        
        if final_test_name != original_name:
            break
        else:
            final_test_name = list(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme        Category  \
# 0  UID-250  Names where name parts are Modified  Transpositions
# 1  UID-250  Names where name parts are Modified  Transpositions
# 2  UID-250  Names where name parts are Modified  Transpositions
# 3  UID-250  Names where name parts are Modified  Transpositions
# 4  UID-250  Names where name parts are Modified  Transpositions
# 5  UID-250  Names where name parts are Modified  Transpositions
# 6  UID-250  Names where name parts are Modified  Transpositions
# 7  UID-250  Names where name parts are Modified  Transpositions
# 8  UID-250  Names where name parts are Modified  Transpositions
# 9  UID-250  Names where name parts are Modified  Transpositions
#
#                                      Sub-category Entity-Type  \
# 0  1 transposition - more than 2 letters anywhere      Entity
# 1  1 transposition - more than 2 letters anywhere      Entity
# 2  1 transposition - more than 2 letters anywhere      Entity
# 3  1 transposition - more than 2 letters anywhere      Entity
# 4  1 transposition - more than 2 letters anywhere      Entity
# 5  1 transposition - more than 2 letters anywhere      Entity
# 6  1 transposition - more than 2 letters anywhere      Entity
# 7  1 transposition - more than 2 letters anywhere      Entity
# 8  1 transposition - more than 2 letters anywhere      Entity
# 9  1 transposition - more than 2 letters anywhere      Entity
#
#       Test Case ID OFAC List UID  \
# 0  UID-250 - 10670         37901
# 1   UID-250 - 3633         16860
# 2   UID-250 - 7983         29853
# 3   UID-250 - 7741         29019
# 4   UID-250 - 8896         33883
# 5     UID-250 - 90          4697
# 6   UID-250 - 8946         33996
# 7   UID-250 - 3972         18093
# 8   UID-250 - 8426         31415
# 9   UID-250 - 3793         17243
#
#                                        Original Name  \
# 0  TEO BOON CHING WILDLIFE TRAFFICKING TRANSNATIO...
# 1                                           TEMPBANK
# 2                              ATLAS SHIP MANAGEMENT
# 3                                   KALAI INDUSTRIES
# 4             ZARKO VESELINOVIC B.I., S.T.R. KRISTAL
# 5                                          HIZBALLAH
# 6                          P.P.ROBNA KUCA METAL B.I.
# 7                    AHOME REAL ESTATE, S.A. DE C.V.
# 8  FEDERAL STATE AUTONOMOUS SCIENTIFIC ESTABLISHM...
# 9                                    INDUSTRIAL BANK
#
#                                       Test Case Name
# 0  TEO BON CHGOIN WILDNKIE FRAFTFICING TRMASNTINO...
# 1                                           ANEPBKMT
# 2                              NATSLAA HP MIAGEMESNT
# 3                                   KLAUA SNDTIRIIES
# 4             AI SOVELILVICOK EB.T., ..R.S KZIRNSTRA
# 5                                          HLILHZABA
# 6                          .P.PRBELNA KUO AM TB.IC.A
# 7                    AAOM RED EETAST, CA..ESH E L.V.
# 8  UEETIAFL TINAT ACUOROFUS SDSCINIFIC ESTEBSLIES...
# 9                                    IIKNDUTSARAL BN
