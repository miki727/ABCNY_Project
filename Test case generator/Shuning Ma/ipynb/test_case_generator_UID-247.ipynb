# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet, num_of_alphabet

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-247' 
theme = 'Names where name parts are Modified'
category = 'Transpositions'
sub_category = '1 transposition - 2 letters Any where'
entity_type = 'Entity'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == '-0- ')] # only evaluate entities

# %% [markdown]
# ## randomly choose 10 rows

# %%
while True:
    ofac_list_sampled = ofac_list_filtered.sample(n = 10)
    cnt = [0] * 10
    for ind, name in enumerate(ofac_list_sampled['name']):
        
        if len(name) > 10:
            cnt[ind] += 1

    if all(i == 1 for i in cnt):
        break

ofac_list_sampled
# Out:
#          uid                                               name entity_type
# 9877   35996  OPEN JOINT STOCK COMPANY ILYUSHIN AVIATION COM...        -0-
# 7682   28687                 MIDDLE EAST SAMAN CHEMICAL COMPANY        -0-
# 907     8375                     IRAQI FREIGHT SERVICES LIMITED        -0-
# 7779   29101                                      M INVEST, OOO        -0-
# 8153   30398                              HEJAB TEXTILE COMPANY        -0-
# 4017   18250                 MORGAN ADDITIVES MANUFACTURING CO.        -0-
# 7475   28123                                        ARANEKS DOO        -0-
# 5372   22943               SADID CARAN SABA ENGINEERING COMPANY        -0-
# 764     8177                         LOT 3A OF DETE VALLEY FARM        -0-
# 10611  37805                                AO NPP TSIKLON TEST        -0-

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    split_original_name = original_name.split(' ') # split name into word
    final_test_name = split_original_name.copy()
    
    while True:
        replace_word = np.random.choice(split_original_name) # randomly choose word to be transposed
        if num_of_alphabet(replace_word) < 2:
            continue
        
        replace_word_list = list(replace_word)
        replace_word_index = list(range(len(replace_word)))
        replace_index = np.random.choice(replace_word_index) # choose letter to be transposed
        
        if replace_word_list[replace_index] not in alphabet():
            continue
        
        if replace_index == 0:
            if replace_word_list[1] not in alphabet():
                continue
            else:
                replace_word_list.insert(0, replace_word_list.pop(1)) # transpose
        
        elif replace_index == len(replace_word_list) - 1:
            if replace_word_list[-2] not in alphabet():
                continue
            else:
                replace_word_list.insert(-1, replace_word_list.pop(-2)) # transpose
        
        else:
            if (replace_word_list[replace_index + 1] not in alphabet()) & (replace_word_list[replace_index - 1] not in alphabet()):
                continue
            elif replace_word_list[replace_index + 1] not in alphabet():
                replace_word_list.insert(replace_index, replace_word_list.pop(replace_index - 1)) # transpose
            elif replace_word_list[replace_index - 1] not in alphabet():
                replace_word_list.insert(replace_index, replace_word_list.pop(replace_index + 1)) # transpose
            else:
                random_choice = np.random.choice([-1, 1])
                replace_word_list.insert(replace_index, replace_word_list.pop(replace_index + random_choice)) # transpose
        
        if replace_word == ''.join(replace_word_list):
            continue
        else:
            break

    final_test_name[final_test_name.index(replace_word)] = ''.join(replace_word_list)

    final_test_name = ' '.join(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme        Category  \
# 0  UID-247  Names where name parts are Modified  Transpositions
# 1  UID-247  Names where name parts are Modified  Transpositions
# 2  UID-247  Names where name parts are Modified  Transpositions
# 3  UID-247  Names where name parts are Modified  Transpositions
# 4  UID-247  Names where name parts are Modified  Transpositions
# 5  UID-247  Names where name parts are Modified  Transpositions
# 6  UID-247  Names where name parts are Modified  Transpositions
# 7  UID-247  Names where name parts are Modified  Transpositions
# 8  UID-247  Names where name parts are Modified  Transpositions
# 9  UID-247  Names where name parts are Modified  Transpositions
#
#                             Sub-category Entity-Type     Test Case ID  \
# 0  1 transposition - 2 letters Any where      Entity   UID-247 - 9877
# 1  1 transposition - 2 letters Any where      Entity   UID-247 - 7682
# 2  1 transposition - 2 letters Any where      Entity    UID-247 - 907
# 3  1 transposition - 2 letters Any where      Entity   UID-247 - 7779
# 4  1 transposition - 2 letters Any where      Entity   UID-247 - 8153
# 5  1 transposition - 2 letters Any where      Entity   UID-247 - 4017
# 6  1 transposition - 2 letters Any where      Entity   UID-247 - 7475
# 7  1 transposition - 2 letters Any where      Entity   UID-247 - 5372
# 8  1 transposition - 2 letters Any where      Entity    UID-247 - 764
# 9  1 transposition - 2 letters Any where      Entity  UID-247 - 10611
#
#   OFAC List UID                                      Original Name  \
# 0         35996  OPEN JOINT STOCK COMPANY ILYUSHIN AVIATION COM...
# 1         28687                 MIDDLE EAST SAMAN CHEMICAL COMPANY
# 2          8375                     IRAQI FREIGHT SERVICES LIMITED
# 3         29101                                      M INVEST, OOO
# 4         30398                              HEJAB TEXTILE COMPANY
# 5         18250                 MORGAN ADDITIVES MANUFACTURING CO.
# 6         28123                                        ARANEKS DOO
# 7         22943               SADID CARAN SABA ENGINEERING COMPANY
# 8          8177                         LOT 3A OF DETE VALLEY FARM
# 9         37805                                AO NPP TSIKLON TEST
#
#                                       Test Case Name
# 0  OPEN JOINT STOCK COMPANY ILYUSHIN AVIATION OCM...
# 1                 MIDDLE AEST SAMAN CHEMICAL COMPANY
# 2                     IRAQI FREIGHT ESRVICES LIMITED
# 3                                      M NIVEST, OOO
# 4                              HEJAB TEXTILE COPMANY
# 5                 MORGAN ADDITIVES MANUFACTURNIG CO.
# 6                                        ARANEKS ODO
# 7               SADID CARAN SABA NEGINEERING COMPANY
# 8                         LOT 3A OF DTEE VALLEY FARM
# 9                                AO PNP TSIKLON TEST
