# %% [markdown]
# # IMPORT DATA, PACKAGES, AND FUNCTIONS

# %% [markdown]
# ## import the relevant functions and packages

# %%
import pandas as pd
import numpy as np
from test_case_generator_functions import alphabet

# %% [markdown]
# # TEST CASE TYPE REFERENCE INFORMATION

# %%
uid = 'UID-238' 
theme = 'Names where name parts are Modified'
category = 'Repetitions'
sub_category = '2 letters repeated twice'
entity_type = 'Entity'

# %% [markdown]
# ## download the OFAC list from the web

# %%
ofac_list_download = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header=None)

# %%
ofac_list = ofac_list_download[[0,1,2]]
ofac_list.columns = ['uid', 'name', 'entity_type']

# %% [markdown]
# # FILTER FOR THE REQUIREMENTS OF THE TEST CASE TYPE

# %% [markdown]
# ## filter for the requirements of the specific test case type

# %%
ofac_list_filtered = ofac_list[(ofac_list.entity_type == '-0- ')] # only evaluate entities

# %% [markdown]
# ## randomly choose 10 rows

# %%
while True:
    ofac_list_sampled = ofac_list_filtered.sample(n = 10)
    cnt = [0] * 10
    for ind, name in enumerate(ofac_list_sampled['name']):
        split_name = name.upper().split(' ')
        
        for i in split_name:
            if all(j not in alphabet() for j in i):
                split_name.remove(i) # remove word with all numbers
                
        cnt[ind] += len(split_name)

    if all(i >= 2 for i in cnt):
        break

ofac_list_sampled
# Out:
#          uid                                               name entity_type
# 2669   13356                          I&S HOLDING COMPANY, S.A.        -0-
# 5800   23763                     CHANG AN SHIPPING & TECHNOLOGY        -0-
# 4448   19733                                  AYDAH TRADING LLC        -0-
# 3499   16607     PRODUCCION PESQUERA DONA MARIELA, S.A. DE C.V.        -0-
# 10599  37800  AKTSIONERNOE OBSHCHESTVO RYAZANSKII ZAVOD META...        -0-
# 4176   18737           VTB REGISTRAR CLOSED JOINT STOCK COMPANY        -0-
# 170     6826                                      GALAPAGOS S.A        -0-
# 1521   10495                                       HARA COMPANY        -0-
# 9975   36367  LIMITED LIABILITY COMPANY RUSSIAN DIGITAL SOLU...        -0-
# 6488   25634               TOSE-E DIDAR IRANIAN HOLDING COMPANY        -0-

# %% [markdown]
# # CREATE THE TEST CASES

# %% [markdown]
# ## create blank final test cases table

# %%
final_test_cases = pd.DataFrame(columns=['UID', 'Theme','Category','Sub-category','Entity-Type','Test Case ID' , 'OFAC List UID', 'Original Name','Test Case Name'])
final_test_cases
# Out:
# Empty DataFrame
# Columns: [UID, Theme, Category, Sub-category, Entity-Type, Test Case ID, OFAC List UID, Original Name, Test Case Name]
# Index: []

# %% [markdown]
# ## run loop to generate the test cases

# %%
for index, row in ofac_list_sampled.iterrows():
    original_name = row['name'].upper()
    split_original_name = original_name.split(' ') # split name into word
    final_test_name = split_original_name.copy()
    
    for i in split_original_name:
        if all(j not in alphabet() for j in i):
            split_original_name.remove(i) # remove word with all numbers
        
    for i in range(2):
        replace_word = np.random.choice(split_original_name) # randomly choose word to be replaced
        split_original_name.remove(replace_word) # remove chosen word
        
        replace_word_list = list(replace_word)
        repeat_list = [] # get index of alphabets in each word
        for i in range(len(replace_word)):
            if replace_word[i] in alphabet():
                repeat_list.append(i)
        
        random_index = np.random.choice(repeat_list) # randomly choose letter to be repeated
        
        replace_word_list[random_index] += replace_word_list[random_index] + replace_word_list[random_index] # add repeated letter twice
        
        final_test_name[final_test_name.index(replace_word)] = ''.join(replace_word_list)

    final_test_name = ' '.join(final_test_name)
    
    final_test_cases.loc[len(final_test_cases)] = [uid, theme, category, sub_category, entity_type, uid + ' - ' + str(index), row['uid'], row['name'], final_test_name] # append to the dataframe

final_test_cases
# Out:
#        UID                                Theme     Category  \
# 0  UID-238  Names where name parts are Modified  Repetitions
# 1  UID-238  Names where name parts are Modified  Repetitions
# 2  UID-238  Names where name parts are Modified  Repetitions
# 3  UID-238  Names where name parts are Modified  Repetitions
# 4  UID-238  Names where name parts are Modified  Repetitions
# 5  UID-238  Names where name parts are Modified  Repetitions
# 6  UID-238  Names where name parts are Modified  Repetitions
# 7  UID-238  Names where name parts are Modified  Repetitions
# 8  UID-238  Names where name parts are Modified  Repetitions
# 9  UID-238  Names where name parts are Modified  Repetitions
#
#                Sub-category Entity-Type     Test Case ID OFAC List UID  \
# 0  2 letters repeated twice      Entity   UID-238 - 2669         13356
# 1  2 letters repeated twice      Entity   UID-238 - 5800         23763
# 2  2 letters repeated twice      Entity   UID-238 - 4448         19733
# 3  2 letters repeated twice      Entity   UID-238 - 3499         16607
# 4  2 letters repeated twice      Entity  UID-238 - 10599         37800
# 5  2 letters repeated twice      Entity   UID-238 - 4176         18737
# 6  2 letters repeated twice      Entity    UID-238 - 170          6826
# 7  2 letters repeated twice      Entity   UID-238 - 1521         10495
# 8  2 letters repeated twice      Entity   UID-238 - 9975         36367
# 9  2 letters repeated twice      Entity   UID-238 - 6488         25634
#
#                                        Original Name  \
# 0                          I&S HOLDING COMPANY, S.A.
# 1                     CHANG AN SHIPPING & TECHNOLOGY
# 2                                  AYDAH TRADING LLC
# 3     PRODUCCION PESQUERA DONA MARIELA, S.A. DE C.V.
# 4  AKTSIONERNOE OBSHCHESTVO RYAZANSKII ZAVOD META...
# 5           VTB REGISTRAR CLOSED JOINT STOCK COMPANY
# 6                                      GALAPAGOS S.A
# 7                                       HARA COMPANY
# 8  LIMITED LIABILITY COMPANY RUSSIAN DIGITAL SOLU...
# 9               TOSE-E DIDAR IRANIAN HOLDING COMPANY
#
#                                       Test Case Name
# 0                      I&S HOLLLDING COMPANY, S.AAA.
# 1                 CHANG ANNN SHIPPING & TECHNOLOOOGY
# 2                              AAAYDAH TRADING LLLLC
# 3  PRODUCCION PESQUUUERA DOOONA MARIELA, S.A. DE ...
# 4  AKTSIONERNOE OBSHCHEEESTVO RYAZANSKII ZZZAVOD ...
# 5       VTB REGISTTTRAR CLOSED JOINT STOCCCK COMPANY
# 6                                  GALAPAGOSSS S.AAA
# 7                                   HAAARA COMPANYYY
# 8  LIMITED LIABILITY COOOMPANY RRRUSSIAN DIGITAL ...
# 9           TOSSSE-E DIDAR IRANIAAAN HOLDING COMPANY
